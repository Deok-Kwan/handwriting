# %%
import re
import os
import cv2
import numpy as np
import pandas as pd
import easyocr
import torch

############################################
# 0) GPU 설정
############################################
torch.cuda.set_device(3)
print(f"PyTorch CUDA Available: {torch.cuda.is_available()}")
print(f"Current Device Index: {torch.cuda.current_device()}")

############################################
# 1) 파일명 -> (writer_id, prompt) 파싱 함수
############################################
def parse_filename(fname: str):
    """
    예: w0001_s01_pLND_r01.png
     -> writer_id=1, prompt="LND"
    session 등은 무시
    """
    parts = fname.split("_")
    writer_str = parts[0]  # "w0001"
    prompt_str = parts[2] # "pLND"

    writer_id_num = int(writer_str.replace("w",""))
    prompt_code = prompt_str.replace("p","")  # "LND","PHR","WOZ" 등
    return writer_id_num, prompt_code

############################################
# 2) 라인 세그먼트 & OCR
############################################
def segment_lines_by_projection(
    image_path: str,
    threshold_val: int = 150,
    min_line_height: int = 10
):
    img_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img_gray is None:
        raise FileNotFoundError(f"Could not read the image file: {image_path}")
    
    # 글자=0, 배경=255
    _, bin_img = cv2.threshold(img_gray, threshold_val, 255, cv2.THRESH_BINARY)
    inverted = 255 - bin_img  # 글자=255, 배경=0
    h, w = inverted.shape
    horizontal_projection = np.sum(inverted, axis=1)

    line_boxes = []
    in_line = False
    line_start = 0

    for y in range(h):
        if horizontal_projection[y] > 0:
            if not in_line:
                in_line = True
                line_start = y
        else:
            if in_line:
                line_end = y
                if (line_end - line_start) > min_line_height:
                    line_boxes.append((line_start, line_end))
                in_line = False
    
    if in_line:
        line_end = h
        if (line_end - line_start) > min_line_height:
            line_boxes.append((line_start, line_end))

    return line_boxes, img_gray, bin_img

def recognize_line_image(line_image: np.ndarray, reader) -> str:
    results = reader.recognize(line_image, detail=1)
    texts = [r[-2] for r in results]
    return " ".join(texts)

def process_document_lines_no_detector(
    doc_image_path: str,
    seg_output_dir: str,
    prefix: str = "doc",
    threshold_val: int = 150,
    min_line_h: int = 10,
    min_black_pixels: int = 9000,
    reader=None
):
    line_boxes, img_gray, bin_img = segment_lines_by_projection(
        image_path=doc_image_path,
        threshold_val=threshold_val,
        min_line_height=min_line_h
    )
    h, w = bin_img.shape
    os.makedirs(seg_output_dir, exist_ok=True)

    ocr_results = []
    valid_idx = 0

    for i, (ystart, yend) in enumerate(line_boxes):
        cropped_bin = bin_img[ystart:yend, 0:w]

        total_px = cropped_bin.size
        background_count = cv2.countNonZero(cropped_bin)
        black_pixels = total_px - background_count

        if black_pixels < min_black_pixels:
            continue

        cropped_gray = img_gray[ystart:yend, 0:w]

        line_filename = f"{prefix}_line_{valid_idx}.png"
        save_path = os.path.join(seg_output_dir, line_filename)
        cv2.imwrite(save_path, cropped_gray)

        line_text = recognize_line_image(cropped_gray, reader=reader)
        ocr_results.append(line_text)
        valid_idx += 1

    return ocr_results

############################################
# 3) 메인: Writer별 1개만 뽑기 => 2줄 이상 라인만 OCR
############################################
if __name__ == "__main__":
    input_dir = "/workspace/Hand/original"
    seg_dir   = "/workspace/MIL/line_segments"
    os.makedirs(seg_dir, exist_ok=True)

    file_list = [f for f in os.listdir(input_dir) if f.lower().endswith(".png")]

    data_rows = []
    for fname in file_list:
        writer_id, prompt = parse_filename(fname)
        full_path = os.path.join(input_dir, fname)
        data_rows.append({
            "writer_id": writer_id,
            "prompt": prompt,
            "file_path": full_path
        })

    df = pd.DataFrame(data_rows, columns=["writer_id","prompt","file_path"])

    # 1) Writer별 그룹핑 -> 각 그룹에서 1개만 추출
    sample_list = []
    for w_id, group in df.groupby("writer_id"):
        # group 내 임의 1개
        if len(group) > 0:
            chosen = group.sample(n=1, random_state=42)
            sample_list.append(chosen)

    final_sample_df = pd.concat(sample_list, ignore_index=True)
    print("샘플링된 문서 개수:", len(final_sample_df))

    # 2) EasyOCR
    reader = easyocr.Reader(["ko","en"], gpu=True, detector=False, recognizer=True)
    if hasattr(reader.recognizer, 'module'):
        reader.recognizer = reader.recognizer.module

    # 3) 2줄 이상 (검정 픽셀 >= min_black_pixels) 라인만 저장 & OCR
    MIN_BLACK_PIXELS = 9000

    for idx, row in final_sample_df.iterrows():
        writer_id = row["writer_id"]
        prompt    = row["prompt"]
        file_path = row["file_path"]

        prefix = f"w{writer_id:04d}_p{prompt}"

        print(f"Processing: {file_path} (writer={writer_id}, prompt={prompt})")

        results = process_document_lines_no_detector(
            doc_image_path=file_path,
            seg_output_dir=seg_dir,
            prefix=prefix,
            threshold_val=150,
            min_line_h=10,
            min_black_pixels=MIN_BLACK_PIXELS,
            reader=reader
        )

        for line_idx, line_text in enumerate(results):
            print(f"File {file_path} - FilteredLine {line_idx}: {line_text}")

    torch.cuda.empty_cache()
# Out:
# PyTorch CUDA Available: True
# Current Device Index: 3
# 샘플링된 문서 개수: 475
# Processing: /workspace/Hand/original/w0001_s01_pWOZ_r03.png (writer=1, prompt=WOZ)
# File /workspace/Hand/original/w0001_s01_pWOZ_r03.png - FilteredLine 0: 탤려포움
# Processing: /workspace/Hand/original/w0002_s01_pWOZ_r03.png (writer=2, prompt=WOZ)
# Processing: /workspace/Hand/original/w0003_s01_pWOZ_r03.png (writer=3, prompt=WOZ)
# File /workspace/Hand/original/w0003_s01_pWOZ_r03.png - FilteredLine 0: egarraaramragtaamarani
# Processing: /workspace/Hand/original/w0004_s01_pWOZ_r03.png (writer=4, prompt=WOZ)
# File /workspace/Hand/original/w0004_s01_pWOZ_r03.png - FilteredLine 0:  tn   키sha tiu   Ahu uur
# File /workspace/Hand/original/w0004_s01_pWOZ_r03.png - FilteredLine 1:  Wwlkiwj   bwsklv twid . Cu
# File /workspace/Hand/original/w0004_s01_pWOZ_r03.png - FilteredLine 2: 훌포?
# Processing: /workspace/Hand/original/w0005_s01_pWOZ_r03.png (writer=5, prompt=WOZ)
# File /workspace/Hand/original/w0005_s01_pWOZ_r03.png - FilteredLine 0: 콤플 로 로
# Processing: /workspace/Hand/original/w0006_s01_pWOZ_r03.png (writer=6, prompt=WOZ)
# File /workspace/Hand/original/w0006_s01_pWOZ_r03.png - FilteredLine 0: @3 쪽교:
# Processing: /workspace/Hand/original/w0009_s01_pWOZ_r03.png (writer=9, prompt=WOZ)
# File /workspace/Hand/original/w0009_s01_pWOZ_r03.png - FilteredLine 0: 무 까""a  'AP소 }" h
# File /workspace/Hand/original/w0009_s01_pWOZ_r03.png - FilteredLine 1: 무_"" nawnirvi aimnisn" aSnan?
# Processing: /workspace/Hand/original/w0010_s01_pWOZ_r03.png (writer=10, prompt=WOZ)
# File /workspace/Hand/original/w0010_s01_pWOZ_r03.png - FilteredLine 0: 로 67 3713"
# File /workspace/Hand/original/w0010_s01_pWOZ_r03.png - FilteredLine 1: '";"3 W"
# Processing: /workspace/Hand/original/w0011_s01_pWOZ_r03.png (writer=11, prompt=WOZ)
# Processing: /workspace/Hand/original/w0012_s01_pWOZ_r03.png (writer=12, prompt=WOZ)
# Processing: /workspace/Hand/original/w0013_s01_pWOZ_r03.png (writer=13, prompt=WOZ)
# File /workspace/Hand/original/w0013_s01_pWOZ_r03.png - FilteredLine 0: 출Y {표표
# Processing: /workspace/Hand/original/w0015_s01_pWOZ_r03.png (writer=15, prompt=WOZ)
# File /workspace/Hand/original/w0015_s01_pWOZ_r03.png - FilteredLine 0: prarasaruarwraaanass
# File /workspace/Hand/original/w0015_s01_pWOZ_r03.png - FilteredLine 1: ssicu arrtrriiia nitthuoiaiiisi
# File /workspace/Hand/original/w0015_s01_pWOZ_r03.png - FilteredLine 2: eGian ccuintiitiinl님 'ciaoriciatiiairttsr' B
# Processing: /workspace/Hand/original/w0016_s01_pWOZ_r03.png (writer=16, prompt=WOZ)
# File /workspace/Hand/original/w0016_s01_pWOZ_r03.png - FilteredLine 0: oBa saxitos aran poia"ZauthisiaassESr"nakaraaNnd
# Processing: /workspace/Hand/original/w0017_s01_pWOZ_r03.png (writer=17, prompt=WOZ)
# Processing: /workspace/Hand/original/w0018_s01_pWOZ_r03.png (writer=18, prompt=WOZ)
# File /workspace/Hand/original/w0018_s01_pWOZ_r03.png - FilteredLine 0: 출론
# Processing: /workspace/Hand/original/w0020_s01_pWOZ_r03.png (writer=20, prompt=WOZ)
# File /workspace/Hand/original/w0020_s01_pWOZ_r03.png - FilteredLine 0: 훌륭:
# Processing: /workspace/Hand/original/w0022_s01_pWOZ_r03.png (writer=22, prompt=WOZ)
# File /workspace/Hand/original/w0022_s01_pWOZ_r03.png - FilteredLine 0: 기쩍물:
# Processing: /workspace/Hand/original/w0023_s01_pWOZ_r03.png (writer=23, prompt=WOZ)
# File /workspace/Hand/original/w0023_s01_pWOZ_r03.png - FilteredLine 0: @불하하:
# Processing: /workspace/Hand/original/w0024_s01_pWOZ_r03.png (writer=24, prompt=WOZ)
# Processing: /workspace/Hand/original/w0025_s01_pWOZ_r03.png (writer=25, prompt=WOZ)
# File /workspace/Hand/original/w0025_s01_pWOZ_r03.png - FilteredLine 0: 훌출륭
# Processing: /workspace/Hand/original/w0026_s01_pWOZ_r03.png (writer=26, prompt=WOZ)
# Processing: /workspace/Hand/original/w0027_s01_pWOZ_r03.png (writer=27, prompt=WOZ)
# File /workspace/Hand/original/w0027_s01_pWOZ_r03.png - FilteredLine 0: airsr" Jnnjis rxz &4*n숙
# File /workspace/Hand/original/w0027_s01_pWOZ_r03.png - FilteredLine 1: rrt_Y"nsinna
# Processing: /workspace/Hand/original/w0028_s01_pWOZ_r03.png (writer=28, prompt=WOZ)
# File /workspace/Hand/original/w0028_s01_pWOZ_r03.png - FilteredLine 0: 물품
# Processing: /workspace/Hand/original/w0029_s01_pWOZ_r03.png (writer=29, prompt=WOZ)
# File /workspace/Hand/original/w0029_s01_pWOZ_r03.png - FilteredLine 0: "골품록
# Processing: /workspace/Hand/original/w0030_s01_pWOZ_r03.png (writer=30, prompt=WOZ)
# Processing: /workspace/Hand/original/w0031_s01_pWOZ_r03.png (writer=31, prompt=WOZ)
# Processing: /workspace/Hand/original/w0032_s01_pWOZ_r03.png (writer=32, prompt=WOZ)
# File /workspace/Hand/original/w0032_s01_pWOZ_r03.png - FilteredLine 0: 훌기:롭표
# Processing: /workspace/Hand/original/w0033_s01_pWOZ_r03.png (writer=33, prompt=WOZ)
# File /workspace/Hand/original/w0033_s01_pWOZ_r03.png - FilteredLine 0: ~rrimn; anperna Vilais-aasueg"is #niy
# File /workspace/Hand/original/w0033_s01_pWOZ_r03.png - FilteredLine 1:  srirtrg거 rpnaieBfas j0c Sitoh" noaty
# File /workspace/Hand/original/w0033_s01_pWOZ_r03.png - FilteredLine 2: (aniszidCsadifropniocroisrycouatdiciniY어
# Processing: /workspace/Hand/original/w0034_s01_pWOZ_r03.png (writer=34, prompt=WOZ)
# File /workspace/Hand/original/w0034_s01_pWOZ_r03.png - FilteredLine 0: 훌훈러국록
# Processing: /workspace/Hand/original/w0035_s01_pWOZ_r03.png (writer=35, prompt=WOZ)
# File /workspace/Hand/original/w0035_s01_pWOZ_r03.png - FilteredLine 0: 훌운록
# Processing: /workspace/Hand/original/w0036_s01_pWOZ_r03.png (writer=36, prompt=WOZ)
# File /workspace/Hand/original/w0036_s01_pWOZ_r03.png - FilteredLine 0:  trrnr #fturrrhw Chp Vias siaHinhhrpa
# File /workspace/Hand/original/w0036_s01_pWOZ_r03.png - FilteredLine 1: '   mexily On+he haraYelokv raddkdd. The Suh
# File /workspace/Hand/original/w0036_s01_pWOZ_r03.png - FilteredLine 2: '  Shore   bright ad +he birds Sar9 Swezt qnd Dorothy
# File /workspace/Hand/original/w0036_s01_pWOZ_r03.png - FilteredLine 3: '   대c ho4 #il harly as hid aS YD mioh4 +hink 여
# File /workspace/Hand/original/w0036_s01_pWOZ_r03.png - FilteredLine 4: '  litk 9미 woull whohd biln Judkenl khisled
# File /workspace/Hand/original/w0036_s01_pWOZ_r03.png - FilteredLine 5: '   Gway fi her own countvy ar 54+ down in
# Processing: /workspace/Hand/original/w0038_s01_pWOZ_r03.png (writer=38, prompt=WOZ)
# File /workspace/Hand/original/w0038_s01_pWOZ_r03.png - FilteredLine 0: 4중하
# Processing: /workspace/Hand/original/w0040_s01_pWOZ_r03.png (writer=40, prompt=WOZ)
# File /workspace/Hand/original/w0040_s01_pWOZ_r03.png - FilteredLine 0: ~trifninai fkthyvigpnin +nnikirn bri mtra
# File /workspace/Hand/original/w0040_s01_pWOZ_r03.png - FilteredLine 1: nrhi nanna #ain n
# Processing: /workspace/Hand/original/w0041_s01_pWOZ_r03.png (writer=41, prompt=WOZ)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 171
#     167 prefix = f"w{writer_id:04d}_p{prompt}"
#     169 print(f"Processing: {file_path} (writer={writer_id}, prompt={prompt})")
# --> 171 results = process_document_lines_no_detector(
#     172     doc_image_path=file_path,
#     173     seg_output_dir=seg_dir,
#     174     prefix=prefix,
#     175     threshold_val=150,
#     176     min_line_h=10,
#     177     min_black_pixels=MIN_BLACK_PIXELS,
#     178     reader=reader
#     179 )
#     181 for line_idx, line_text in enumerate(results):
#     182     print(f"File {file_path} - FilteredLine {line_idx}: {line_text}")
#
# Cell In[11], line 88, in process_document_lines_no_detector(doc_image_path, seg_output_dir, prefix, threshold_val, min_line_h, min_black_pixels, reader)
#      79 def process_document_lines_no_detector(
#      80     doc_image_path: str,
#      81     seg_output_dir: str,
#    (...)
#      86     reader=None
#      87 ):
# ---> 88     line_boxes, img_gray, bin_img = segment_lines_by_projection(
#      89         image_path=doc_image_path,
#      90         threshold_val=threshold_val,
#      91         min_line_height=min_line_h
#      92     )
#      93     h, w = bin_img.shape
#      94     os.makedirs(seg_output_dir, exist_ok=True)
#
# Cell In[11], line 41, in segment_lines_by_projection(image_path, threshold_val, min_line_height)
#      36 def segment_lines_by_projection(
#      37     image_path: str,
#      38     threshold_val: int = 150,
#      39     min_line_height: int = 10
#      40 ):
# ---> 41     img_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
#      42     if img_gray is None:
#      43         raise FileNotFoundError(f"Could not read the image file: {image_path}")
#
# KeyboardInterrupt:

# %%
# !rm -rf /workspace/MIL/line_segments/*

# %%
import re
import os
import cv2
import numpy as np
import pandas as pd
import easyocr
import torch

############################################
# 0) GPU 설정
############################################
# 물리 GPU #3만 사용하도록
torch.cuda.set_device(3)
print(f"PyTorch CUDA Available: {torch.cuda.is_available()}")
print(f"Current Device Index: {torch.cuda.current_device()}")

############################################
# 1) 파일명 -> (writer_id, prompt) 파싱 함수
############################################
def parse_filename(fname: str):
    """
    예: w0001_s01_pWOZ_r01.png
     -> writer_id=1, prompt="WOZ"
    session, r?? 등은 무시
    """
    # split("_") -> ["w0001","s01","pWOZ","r01.png"]
    parts = fname.split("_")
    writer_str = parts[0]  # "w0001"
    prompt_str = parts[2]  # "pWOZ"

    # writer_id=1
    writer_id_num = int(writer_str.replace("w",""))
    # prompt="WOZ"
    prompt_code = prompt_str.replace("p","")  # 예: "LND","PHR","WOZ"

    return writer_id_num, prompt_code

############################################
# 2) 라인 세그먼트 (회색조 + 이진화)
############################################
def segment_lines_by_projection(
    image_path: str,
    threshold_val: int = 150,
    min_line_height: int = 10
):
    """
    1) 원본 (회색조) 이미지
    2) 이진화(글자=0, 배경=255)
    3) 라인 경계(line_boxes) 찾기
    returns line_boxes, img_gray, bin_img
    """
    img_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img_gray is None:
        raise FileNotFoundError(f"Could not read the image file: {image_path}")

    # 글자=0, 배경=255
    _, bin_img = cv2.threshold(img_gray, threshold_val, 255, cv2.THRESH_BINARY)
    inverted = 255 - bin_img  # 글자=255, 배경=0

    h, w = inverted.shape
    horizontal_projection = np.sum(inverted, axis=1)

    line_boxes = []
    in_line = False
    line_start = 0

    for y in range(h):
        if horizontal_projection[y] > 0:
            if not in_line:
                in_line = True
                line_start = y
        else:
            if in_line:
                line_end = y
                if (line_end - line_start) > min_line_height:
                    line_boxes.append((line_start, line_end))
                in_line = False

    if in_line:
        line_end = h
        if (line_end - line_start) > min_line_height:
            line_boxes.append((line_start, line_end))

    return line_boxes, img_gray, bin_img

############################################
# 3) EasyOCR로 라인 이미지 인식
############################################
def recognize_line_image(line_image: np.ndarray, reader) -> str:
    """
    EasyOCR에 회색조 라인 이미지를 전달해 문자 인식
    """
    results = reader.recognize(line_image, detail=1)
    texts = [r[-2] for r in results]
    return " ".join(texts)

############################################
# 4) 문서 전체 -> 한 줄만 추출 (유효 라인 첫 번째)
############################################
def process_document_lines_no_detector(
    doc_image_path: str,
    seg_output_dir: str,
    prefix: str = "doc",
    threshold_val: int = 150,
    min_line_h: int = 10,
    min_black_pixels: int = 9000,  # "2줄 이상" 기준
    reader=None
):
    """
    1) segment_lines_by_projection -> line_boxes, img_gray, bin_img
    2) 각 line_box에 대해 검정 픽셀 >= min_black_pixels 면 저장+OCR
    3) '첫 번째 유효 라인' 만 추출 -> break
    """
    line_boxes, img_gray, bin_img = segment_lines_by_projection(
        image_path=doc_image_path,
        threshold_val=threshold_val,
        min_line_height=min_line_h
    )

    os.makedirs(seg_output_dir, exist_ok=True)

    valid_idx = 0
    ocr_results = []

    for (ystart, yend) in line_boxes:
        cropped_bin = bin_img[ystart:yend, :]
        total_px = cropped_bin.size
        background_count = cv2.countNonZero(cropped_bin)  # 배경=255
        black_pixels = total_px - background_count         # 글자=0 픽셀 수

        if black_pixels < min_black_pixels:
            # skip
            continue

        # 첫 번째 유효 라인만
        cropped_gray = img_gray[ystart:yend, :]
        line_filename = f"{prefix}_line_{valid_idx}.png"
        cv2.imwrite(os.path.join(seg_output_dir, line_filename), cropped_gray)

        line_text = recognize_line_image(cropped_gray, reader=reader)
        ocr_results.append(line_text)
        valid_idx += 1

        # break -> 한 라인만 저장
        break

    return ocr_results

############################################
# 5) 메인: 작성자별 문서 하나씩 + 한 줄만
############################################
if __name__ == "__main__":
    # GPU, etc.
    input_dir = "/workspace/Hand/original"
    seg_dir   = "/workspace/MIL/line_segments"
    os.makedirs(seg_dir, exist_ok=True)

    file_list = [f for f in os.listdir(input_dir) if f.lower().endswith(".png")]

    # 파싱 (writer_id, prompt)
    data_rows = []
    for fname in file_list:
        writer_id, prompt = parse_filename(fname)
        full_path = os.path.join(input_dir, fname)
        data_rows.append({
            "writer_id": writer_id,
            "prompt": prompt,
            "file_path": full_path
        })

    df = pd.DataFrame(data_rows)

    # 1) 예: Prompt="WOZ" 만 필터링 (원한다면)
    # df = df[df["prompt"]=="WOZ"]  # <- 주석 처리/해제, 필요에 따라

    # 2) 각 writer_id별 1개 문서만 뽑기
    sample_list = []
    for w_id, group in df.groupby("writer_id"):
        if len(group) > 0:
            chosen = group.sample(n=1, random_state=42)
            sample_list.append(chosen)

    final_sample_df = pd.concat(sample_list, ignore_index=True)
    print("Writer별 문서 샘플 수:", len(final_sample_df))

    # 3) EasyOCR
    reader = easyocr.Reader(["ko","en"], gpu=True, detector=False, recognizer=True)
    if hasattr(reader.recognizer, 'module'):
        reader.recognizer = reader.recognizer.module

    # 4) 문서 당 '한 줄'만 (검정 픽셀>=12000)
    MIN_BLACK_PIXELS = 9000

    for idx, row in final_sample_df.iterrows():
        writer_id = row["writer_id"]
        prompt    = row["prompt"]
        file_path = row["file_path"]

        prefix = f"w{writer_id:04d}_p{prompt}"

        print(f"Processing: {file_path} (writer={writer_id}, prompt={prompt})")

        results = process_document_lines_no_detector(
            doc_image_path=file_path,
            seg_output_dir=seg_dir,
            prefix=prefix,
            threshold_val=150,
            min_line_h=10,
            min_black_pixels=MIN_BLACK_PIXELS,
            reader=reader
        )

        for line_idx, line_text in enumerate(results):
            print(f"File {file_path} - FilteredLine {line_idx}: {line_text}")

    torch.cuda.empty_cache()
# Out:
# PyTorch CUDA Available: True
# Current Device Index: 3
# Writer별 문서 샘플 수: 475
# Processing: /workspace/Hand/original/w0001_s01_pWOZ_r03.png (writer=1, prompt=WOZ)
# File /workspace/Hand/original/w0001_s01_pWOZ_r03.png - FilteredLine 0: 탤려포움
# Processing: /workspace/Hand/original/w0002_s01_pWOZ_r03.png (writer=2, prompt=WOZ)
# Processing: /workspace/Hand/original/w0003_s01_pWOZ_r03.png (writer=3, prompt=WOZ)
# File /workspace/Hand/original/w0003_s01_pWOZ_r03.png - FilteredLine 0: egarraaramragtaamarani
# Processing: /workspace/Hand/original/w0004_s01_pWOZ_r03.png (writer=4, prompt=WOZ)
# File /workspace/Hand/original/w0004_s01_pWOZ_r03.png - FilteredLine 0:  tn   키sha tiu   Ahu uur
# Processing: /workspace/Hand/original/w0005_s01_pWOZ_r03.png (writer=5, prompt=WOZ)
# File /workspace/Hand/original/w0005_s01_pWOZ_r03.png - FilteredLine 0: 콤플 로 로
# Processing: /workspace/Hand/original/w0006_s01_pWOZ_r03.png (writer=6, prompt=WOZ)
# File /workspace/Hand/original/w0006_s01_pWOZ_r03.png - FilteredLine 0: @3 쪽교:
# Processing: /workspace/Hand/original/w0009_s01_pWOZ_r03.png (writer=9, prompt=WOZ)
# File /workspace/Hand/original/w0009_s01_pWOZ_r03.png - FilteredLine 0: ' Whin 0 Short firr Sw Uas   WaIy4n9
# Processing: /workspace/Hand/original/w0010_s01_pWOZ_r03.png (writer=10, prompt=WOZ)
# File /workspace/Hand/original/w0010_s01_pWOZ_r03.png - FilteredLine 0: 로 67 3713"
# Processing: /workspace/Hand/original/w0011_s01_pWOZ_r03.png (writer=11, prompt=WOZ)
# Processing: /workspace/Hand/original/w0012_s01_pWOZ_r03.png (writer=12, prompt=WOZ)
# Processing: /workspace/Hand/original/w0013_s01_pWOZ_r03.png (writer=13, prompt=WOZ)
# File /workspace/Hand/original/w0013_s01_pWOZ_r03.png - FilteredLine 0: 출Y {표표
# Processing: /workspace/Hand/original/w0015_s01_pWOZ_r03.png (writer=15, prompt=WOZ)
# File /workspace/Hand/original/w0015_s01_pWOZ_r03.png - FilteredLine 0: prarasaruarwraaanass
# Processing: /workspace/Hand/original/w0016_s01_pWOZ_r03.png (writer=16, prompt=WOZ)
# File /workspace/Hand/original/w0016_s01_pWOZ_r03.png - FilteredLine 0: '   Within 여 shon4 :ime ske uas ualkipg briskly +ouusra +he Ewerald
# Processing: /workspace/Hand/original/w0017_s01_pWOZ_r03.png (writer=17, prompt=WOZ)
# Processing: /workspace/Hand/original/w0018_s01_pWOZ_r03.png (writer=18, prompt=WOZ)
# File /workspace/Hand/original/w0018_s01_pWOZ_r03.png - FilteredLine 0: 출론
# Processing: /workspace/Hand/original/w0020_s01_pWOZ_r03.png (writer=20, prompt=WOZ)
# File /workspace/Hand/original/w0020_s01_pWOZ_r03.png - FilteredLine 0: 훌륭:
# Processing: /workspace/Hand/original/w0022_s01_pWOZ_r03.png (writer=22, prompt=WOZ)
# File /workspace/Hand/original/w0022_s01_pWOZ_r03.png - FilteredLine 0: 기쩍물:
# Processing: /workspace/Hand/original/w0023_s01_pWOZ_r03.png (writer=23, prompt=WOZ)
# File /workspace/Hand/original/w0023_s01_pWOZ_r03.png - FilteredLine 0: @불하하:
# Processing: /workspace/Hand/original/w0024_s01_pWOZ_r03.png (writer=24, prompt=WOZ)
# File /workspace/Hand/original/w0024_s01_pWOZ_r03.png - FilteredLine 0:  jwvarah , shotiwc Ghe rieriaitvrzshngfiy
# Processing: /workspace/Hand/original/w0025_s01_pWOZ_r03.png (writer=25, prompt=WOZ)
# File /workspace/Hand/original/w0025_s01_pWOZ_r03.png - FilteredLine 0: 훌출륭
# Processing: /workspace/Hand/original/w0026_s01_pWOZ_r03.png (writer=26, prompt=WOZ)
# File /workspace/Hand/original/w0026_s01_pWOZ_r03.png - FilteredLine 0:   Wilhto u   short +Rmc shc uas   wulk"g   briskl  +owaru  +he
# Processing: /workspace/Hand/original/w0027_s01_pWOZ_r03.png (writer=27, prompt=WOZ)
# File /workspace/Hand/original/w0027_s01_pWOZ_r03.png - FilteredLine 0: airsr" Jnnjis rxz &4*n숙
# Processing: /workspace/Hand/original/w0028_s01_pWOZ_r03.png (writer=28, prompt=WOZ)
# File /workspace/Hand/original/w0028_s01_pWOZ_r03.png - FilteredLine 0: 물품
# Processing: /workspace/Hand/original/w0029_s01_pWOZ_r03.png (writer=29, prompt=WOZ)
# File /workspace/Hand/original/w0029_s01_pWOZ_r03.png - FilteredLine 0: "골품록
# Processing: /workspace/Hand/original/w0030_s01_pWOZ_r03.png (writer=30, prompt=WOZ)
# File /workspace/Hand/original/w0030_s01_pWOZ_r03.png - FilteredLine 0: ' 4 tt오 오u TSssLskismsAt _내aa'
# Processing: /workspace/Hand/original/w0031_s01_pWOZ_r03.png (writer=31, prompt=WOZ)
# Processing: /workspace/Hand/original/w0032_s01_pWOZ_r03.png (writer=32, prompt=WOZ)
# File /workspace/Hand/original/w0032_s01_pWOZ_r03.png - FilteredLine 0: 훌기:롭표
# Processing: /workspace/Hand/original/w0033_s01_pWOZ_r03.png (writer=33, prompt=WOZ)
# File /workspace/Hand/original/w0033_s01_pWOZ_r03.png - FilteredLine 0: ~rrimn; anperna Vilais-aasueg"is #niy
# Processing: /workspace/Hand/original/w0034_s01_pWOZ_r03.png (writer=34, prompt=WOZ)
# File /workspace/Hand/original/w0034_s01_pWOZ_r03.png - FilteredLine 0: 훌훈러국록
# Processing: /workspace/Hand/original/w0035_s01_pWOZ_r03.png (writer=35, prompt=WOZ)
# File /workspace/Hand/original/w0035_s01_pWOZ_r03.png - FilteredLine 0: 훌운록
# Processing: /workspace/Hand/original/w0036_s01_pWOZ_r03.png (writer=36, prompt=WOZ)
# File /workspace/Hand/original/w0036_s01_pWOZ_r03.png - FilteredLine 0:  trrnr #fturrrhw Chp Vias siaHinhhrpa
# Processing: /workspace/Hand/original/w0038_s01_pWOZ_r03.png (writer=38, prompt=WOZ)
# File /workspace/Hand/original/w0038_s01_pWOZ_r03.png - FilteredLine 0: 4중하
# Processing: /workspace/Hand/original/w0040_s01_pWOZ_r03.png (writer=40, prompt=WOZ)
# File /workspace/Hand/original/w0040_s01_pWOZ_r03.png - FilteredLine 0: ~trifninai fkthyvigpnin +nnikirn bri mtra
# Processing: /workspace/Hand/original/w0041_s01_pWOZ_r03.png (writer=41, prompt=WOZ)
# File /workspace/Hand/original/w0041_s01_pWOZ_r03.png - FilteredLine 0: @출표-
# Processing: /workspace/Hand/original/w0042_s01_pWOZ_r03.png (writer=42, prompt=WOZ)
# File /workspace/Hand/original/w0042_s01_pWOZ_r03.png - FilteredLine 0:  #
# Processing: /workspace/Hand/original/w0043_s01_pWOZ_r03.png (writer=43, prompt=WOZ)
# File /workspace/Hand/original/w0043_s01_pWOZ_r03.png - FilteredLine 0: ' Luithn 9 Swun fiwl   She  uas (alkiys briskly Ticl 7kC   Ewedld  ChY'
# Processing: /workspace/Hand/original/w0049_s01_pWOZ_r03.png (writer=49, prompt=WOZ)
# Processing: /workspace/Hand/original/w0058_s01_pWOZ_r03.png (writer=58, prompt=WOZ)
# Processing: /workspace/Hand/original/w0061_s01_pWOZ_r03.png (writer=61, prompt=WOZ)
# File /workspace/Hand/original/w0061_s01_pWOZ_r03.png - FilteredLine 0:  콤륭-?
# Processing: /workspace/Hand/original/w0062_s01_pWOZ_r03.png (writer=62, prompt=WOZ)
# File /workspace/Hand/original/w0062_s01_pWOZ_r03.png - FilteredLine 0: Winm & Ahyu n  Ah uai Uall4n
# Processing: /workspace/Hand/original/w0063_s01_pWOZ_r03.png (writer=63, prompt=WOZ)
# Processing: /workspace/Hand/original/w0064_s01_pWOZ_r03.png (writer=64, prompt=WOZ)
# File /workspace/Hand/original/w0064_s01_pWOZ_r03.png - FilteredLine 0: 콤l균3운동;
# Processing: /workspace/Hand/original/w0066_s01_pWOZ_r03.png (writer=66, prompt=WOZ)
# File /workspace/Hand/original/w0066_s01_pWOZ_r03.png - FilteredLine 0: 불운로쪽"
# Processing: /workspace/Hand/original/w0069_s01_pWOZ_r03.png (writer=69, prompt=WOZ)
# File /workspace/Hand/original/w0069_s01_pWOZ_r03.png - FilteredLine 0: ' Ewrald Citu h< Siluer   Shccs  intlvng rrrrily  Ch fk hard ipllciu
# Processing: /workspace/Hand/original/w0070_s01_pWOZ_r03.png (writer=70, prompt=WOZ)
# File /workspace/Hand/original/w0070_s01_pWOZ_r03.png - FilteredLine 0: "i"" n"rbns '" 9i""*#*1 ,prarni . j__ jr"
# Processing: /workspace/Hand/original/w0071_s01_pWOZ_r03.png (writer=71, prompt=WOZ)
# File /workspace/Hand/original/w0071_s01_pWOZ_r03.png - FilteredLine 0: en GasnrrrPrteas paanl nrmar
# Processing: /workspace/Hand/original/w0073_s01_pWOZ_r03.png (writer=73, prompt=WOZ)
# File /workspace/Hand/original/w0073_s01_pWOZ_r03.png - FilteredLine 0:   Wlhi a Ji) #we Je wa Walliw bnsl lawavd Yse Ewkll Gk Mersllier
# Processing: /workspace/Hand/original/w0074_s01_pWOZ_r03.png (writer=74, prompt=WOZ)
# File /workspace/Hand/original/w0074_s01_pWOZ_r03.png - FilteredLine 0:  소iusss t*tasprns " 보" kis Dwan'혜srfl %
# Processing: /workspace/Hand/original/w0075_s01_pWOZ_r03.png (writer=75, prompt=WOZ)
# File /workspace/Hand/original/w0075_s01_pWOZ_r03.png - FilteredLine 0: 협동:
# Processing: /workspace/Hand/original/w0076_s01_pWOZ_r03.png (writer=76, prompt=WOZ)
# File /workspace/Hand/original/w0076_s01_pWOZ_r03.png - FilteredLine 0: {출중운 급:
# Processing: /workspace/Hand/original/w0077_s01_pWOZ_r03.png (writer=77, prompt=WOZ)
# File /workspace/Hand/original/w0077_s01_pWOZ_r03.png - FilteredLine 0: e' pr"""ainnt' "e"' "
# Processing: /workspace/Hand/original/w0078_s01_pWOZ_r03.png (writer=78, prompt=WOZ)
# File /workspace/Hand/original/w0078_s01_pWOZ_r03.png - FilteredLine 0: 또:록
# Processing: /workspace/Hand/original/w0080_s01_pWOZ_r03.png (writer=80, prompt=WOZ)
# File /workspace/Hand/original/w0080_s01_pWOZ_r03.png - FilteredLine 0: '  Utrnu [ prrt Linu Ar las uzlloinu
# Processing: /workspace/Hand/original/w0082_s01_pWOZ_r03.png (writer=82, prompt=WOZ)
# File /workspace/Hand/original/w0082_s01_pWOZ_r03.png - FilteredLine 0: '   Sio- cker +""ul? "arrly 예t karD,telloc- VocOLco . T Su채a brgato0
# Processing: /workspace/Hand/original/w0083_s01_pWOZ_r03.png (writer=83, prompt=WOZ)
# File /workspace/Hand/original/w0083_s01_pWOZ_r03.png - FilteredLine 0: 훈자:
# Processing: /workspace/Hand/original/w0085_s01_pWOZ_r03.png (writer=85, prompt=WOZ)
# File /workspace/Hand/original/w0085_s01_pWOZ_r03.png - FilteredLine 0: '  하
# Processing: /workspace/Hand/original/w0086_s01_pWOZ_r03.png (writer=86, prompt=WOZ)
# File /workspace/Hand/original/w0086_s01_pWOZ_r03.png - FilteredLine 0: ' W(T( A 5fDpr T(ME 5He As 시ALkrNc PPISKLY   TD0APD
# Processing: /workspace/Hand/original/w0087_s01_pWOZ_r03.png (writer=87, prompt=WOZ)
# File /workspace/Hand/original/w0087_s01_pWOZ_r03.png - FilteredLine 0:   Wiwna skot Xml phl was  walkir  briszl
# Processing: /workspace/Hand/original/w0088_s01_pWOZ_r03.png (writer=88, prompt=WOZ)
# File /workspace/Hand/original/w0088_s01_pWOZ_r03.png - FilteredLine 0: 러훈표:
# Processing: /workspace/Hand/original/w0089_s01_pWOZ_r03.png (writer=89, prompt=WOZ)
# File /workspace/Hand/original/w0089_s01_pWOZ_r03.png - FilteredLine 0: 운표출h:
# Processing: /workspace/Hand/original/w0090_s01_pWOZ_r03.png (writer=90, prompt=WOZ)
# File /workspace/Hand/original/w0090_s01_pWOZ_r03.png - FilteredLine 0: @로a포
# Processing: /workspace/Hand/original/w0091_s01_pWOZ_r03.png (writer=91, prompt=WOZ)
# File /workspace/Hand/original/w0091_s01_pWOZ_r03.png - FilteredLine 0:  콤흑다
# Processing: /workspace/Hand/original/w0092_s01_pWOZ_r03.png (writer=92, prompt=WOZ)
# File /workspace/Hand/original/w0092_s01_pWOZ_r03.png - FilteredLine 0:   (wdr @   Ahnt Jisn wia Wnlkin
# Processing: /workspace/Hand/original/w0093_s01_pWOZ_r03.png (writer=93, prompt=WOZ)
# File /workspace/Hand/original/w0093_s01_pWOZ_r03.png - FilteredLine 0: '   WZTrs A Sflo0' TME S4드 wAS  (A4L시c BPZ되L'  TCuAA]
# Processing: /workspace/Hand/original/w0094_s01_pWOZ_r03.png (writer=94, prompt=WOZ)
# File /workspace/Hand/original/w0094_s01_pWOZ_r03.png - FilteredLine 0: ~r" ; #다 &자 rsrs소"
# Processing: /workspace/Hand/original/w0095_s01_pWOZ_r03.png (writer=95, prompt=WOZ)
# File /workspace/Hand/original/w0095_s01_pWOZ_r03.png - FilteredLine 0: lnia " hna  #iiniiina
# Processing: /workspace/Hand/original/w0099_s01_pWOZ_r03.png (writer=99, prompt=WOZ)
# File /workspace/Hand/original/w0099_s01_pWOZ_r03.png - FilteredLine 0: 콤"
# Processing: /workspace/Hand/original/w0102_s01_pWOZ_r03.png (writer=102, prompt=WOZ)
# File /workspace/Hand/original/w0102_s01_pWOZ_r03.png - FilteredLine 0: 표골표소
# Processing: /workspace/Hand/original/w0118_s01_pWOZ_r03.png (writer=118, prompt=WOZ)
# Processing: /workspace/Hand/original/w0119_s01_pWOZ_r03.png (writer=119, prompt=WOZ)
# File /workspace/Hand/original/w0119_s01_pWOZ_r03.png - FilteredLine 0: 탤n훌un품"
# Processing: /workspace/Hand/original/w0121_s01_pWOZ_r03.png (writer=121, prompt=WOZ)
# File /workspace/Hand/original/w0121_s01_pWOZ_r03.png - FilteredLine 0: ' Cityher Silier   skoes   +intling   mervily     +e   hard,   Yellow  rvodled
# Processing: /workspace/Hand/original/w0122_s01_pWOZ_r03.png (writer=122, prompt=WOZ)
# File /workspace/Hand/original/w0122_s01_pWOZ_r03.png - FilteredLine 0:  Withn #smorfetme sheUasetallfin? brisil
# Processing: /workspace/Hand/original/w0123_s01_pWOZ_r03.png (writer=123, prompt=WOZ)
# File /workspace/Hand/original/w0123_s01_pWOZ_r03.png - FilteredLine 0: 훈론로출:
# Processing: /workspace/Hand/original/w0124_s01_pWOZ_r03.png (writer=124, prompt=WOZ)
# File /workspace/Hand/original/w0124_s01_pWOZ_r03.png - FilteredLine 0: 교?
# Processing: /workspace/Hand/original/w0125_s01_pWOZ_r03.png (writer=125, prompt=WOZ)
# File /workspace/Hand/original/w0125_s01_pWOZ_r03.png - FilteredLine 0: "소 축표
# Processing: /workspace/Hand/original/w0126_s01_pWOZ_r03.png (writer=126, prompt=WOZ)
# File /workspace/Hand/original/w0126_s01_pWOZ_r03.png - FilteredLine 0: #출
# Processing: /workspace/Hand/original/w0128_s01_pWOZ_r03.png (writer=128, prompt=WOZ)
# File /workspace/Hand/original/w0128_s01_pWOZ_r03.png - FilteredLine 0: 불로뷰:
# Processing: /workspace/Hand/original/w0129_s01_pWOZ_r03.png (writer=129, prompt=WOZ)
# Processing: /workspace/Hand/original/w0130_s01_pWOZ_r03.png (writer=130, prompt=WOZ)
# File /workspace/Hand/original/w0130_s01_pWOZ_r03.png - FilteredLine 0: u6 5 중갈 # 3어하 ($
# Processing: /workspace/Hand/original/w0131_s01_pWOZ_r03.png (writer=131, prompt=WOZ)
# File /workspace/Hand/original/w0131_s01_pWOZ_r03.png - FilteredLine 0: 운돌넓 콩
# Processing: /workspace/Hand/original/w0132_s01_pWOZ_r03.png (writer=132, prompt=WOZ)
# File /workspace/Hand/original/w0132_s01_pWOZ_r03.png - FilteredLine 0: nksn_n'""n 인3':;'A5 하보하
# Processing: /workspace/Hand/original/w0133_s01_pWOZ_r03.png (writer=133, prompt=WOZ)
# File /workspace/Hand/original/w0133_s01_pWOZ_r03.png - FilteredLine 0:  -하목
# Processing: /workspace/Hand/original/w0134_s01_pWOZ_r03.png (writer=134, prompt=WOZ)
# Processing: /workspace/Hand/original/w0135_s01_pWOZ_r03.png (writer=135, prompt=WOZ)
# File /workspace/Hand/original/w0135_s01_pWOZ_r03.png - FilteredLine 0: '   Wlhin Q shonn cu w? walr brkl toward 4
# Processing: /workspace/Hand/original/w0136_s01_pWOZ_r03.png (writer=136, prompt=WOZ)
# File /workspace/Hand/original/w0136_s01_pWOZ_r03.png - FilteredLine 0: 12333333 하다
# Processing: /workspace/Hand/original/w0137_s01_pWOZ_r03.png (writer=137, prompt=WOZ)
# File /workspace/Hand/original/w0137_s01_pWOZ_r03.png - FilteredLine 0: 운운륭출
# Processing: /workspace/Hand/original/w0138_s01_pWOZ_r03.png (writer=138, prompt=WOZ)
# Processing: /workspace/Hand/original/w0139_s01_pWOZ_r03.png (writer=139, prompt=WOZ)
# File /workspace/Hand/original/w0139_s01_pWOZ_r03.png - FilteredLine 0: '  |kis & pkrt Tc phi w p (Uulhin lwzhi)
# Processing: /workspace/Hand/original/w0142_s01_pWOZ_r03.png (writer=142, prompt=WOZ)
# File /workspace/Hand/original/w0142_s01_pWOZ_r03.png - FilteredLine 0: eeardtenyj etrikfsvis   oupni rriter" dP"a ourarailadd.
# Processing: /workspace/Hand/original/w0143_s01_pWOZ_r03.png (writer=143, prompt=WOZ)
# File /workspace/Hand/original/w0143_s01_pWOZ_r03.png - FilteredLine 0: 무 Wahir " shal hma sh Kns 값lbi bistly   binne
# Processing: /workspace/Hand/original/w0144_s01_pWOZ_r03.png (writer=144, prompt=WOZ)
# File /workspace/Hand/original/w0144_s01_pWOZ_r03.png - FilteredLine 0: 훌륭륭
# Processing: /workspace/Hand/original/w0145_s01_pWOZ_r03.png (writer=145, prompt=WOZ)
# File /workspace/Hand/original/w0145_s01_pWOZ_r03.png - FilteredLine 0:  boriskl니 toiavd   +he   Ep erald  C+ /
# Processing: /workspace/Hand/original/w0146_s01_pWOZ_r03.png (writer=146, prompt=WOZ)
# Processing: /workspace/Hand/original/w0147_s01_pWOZ_r03.png (writer=147, prompt=WOZ)
# File /workspace/Hand/original/w0147_s01_pWOZ_r03.png - FilteredLine 0: 훈물
# Processing: /workspace/Hand/original/w0148_s01_pWOZ_r03.png (writer=148, prompt=WOZ)
# File /workspace/Hand/original/w0148_s01_pWOZ_r03.png - FilteredLine 0: ' (hore   hyit Cxl t   brlc   (어   (eit  "xl   Dirintin   G,4 hut  jt
# Processing: /workspace/Hand/original/w0149_s01_pWOZ_r03.png (writer=149, prompt=WOZ)
# File /workspace/Hand/original/w0149_s01_pWOZ_r03.png - FilteredLine 0: ~요요-국소이 "
# Processing: /workspace/Hand/original/w0150_s01_pWOZ_r03.png (writer=150, prompt=WOZ)
# File /workspace/Hand/original/w0150_s01_pWOZ_r03.png - FilteredLine 0: ' kDishin c skov+ Tipe skc Was LalK' w9 briskly
# Processing: /workspace/Hand/original/w0151_s01_pWOZ_r03.png (writer=151, prompt=WOZ)
# File /workspace/Hand/original/w0151_s01_pWOZ_r03.png - FilteredLine 0: 무 hxasti ostatistrinrs "sx") wxisioairtorgtiaal rorpuit "iij"ssi
# Processing: /workspace/Hand/original/w0152_s01_pWOZ_r03.png (writer=152, prompt=WOZ)
# Processing: /workspace/Hand/original/w0153_s01_pWOZ_r03.png (writer=153, prompt=WOZ)
# File /workspace/Hand/original/w0153_s01_pWOZ_r03.png - FilteredLine 0:  Uitin a Yha사 Huie  Sue w0  Calkis   bvisLly   fuud
# Processing: /workspace/Hand/original/w0154_s01_pWOZ_r03.png (writer=154, prompt=WOZ)
# File /workspace/Hand/original/w0154_s01_pWOZ_r03.png - FilteredLine 0: 훌
# Processing: /workspace/Hand/original/w0155_s01_pWOZ_r03.png (writer=155, prompt=WOZ)
# File /workspace/Hand/original/w0155_s01_pWOZ_r03.png - FilteredLine 0: ' 4/4 ~ 5 5402 / 54 <-
# Processing: /workspace/Hand/original/w0156_s01_pWOZ_r03.png (writer=156, prompt=WOZ)
# File /workspace/Hand/original/w0156_s01_pWOZ_r03.png - FilteredLine 0: ' Wfir %   Shor+ Hre Se Los   W기kiv
# Processing: /workspace/Hand/original/w0157_s01_pWOZ_r03.png (writer=157, prompt=WOZ)
# Processing: /workspace/Hand/original/w0160_s01_pWOZ_r03.png (writer=160, prompt=WOZ)
# File /workspace/Hand/original/w0160_s01_pWOZ_r03.png - FilteredLine 0: '  Wifhin 야 Obor+ tire she Las (alkirg bnsk)y toward   iho
# Processing: /workspace/Hand/original/w0162_s01_pWOZ_r03.png (writer=162, prompt=WOZ)
# File /workspace/Hand/original/w0162_s01_pWOZ_r03.png - FilteredLine 0: ' (iihin ~ ghort +ir   sh  (aS   walkir9
# Processing: /workspace/Hand/original/w0175_s01_pWOZ_r03.png (writer=175, prompt=WOZ)
# File /workspace/Hand/original/w0175_s01_pWOZ_r03.png - FilteredLine 0:   wifhiyrtovmarthiririoarwvniringcr
# Processing: /workspace/Hand/original/w0177_s01_pWOZ_r03.png (writer=177, prompt=WOZ)
# File /workspace/Hand/original/w0177_s01_pWOZ_r03.png - FilteredLine 0: ernhuraatymwsham i TTirtnf "ianf
# Processing: /workspace/Hand/original/w0180_s01_pWOZ_r03.png (writer=180, prompt=WOZ)
# File /workspace/Hand/original/w0180_s01_pWOZ_r03.png - FilteredLine 0: 돌로쪽
# Processing: /workspace/Hand/original/w0182_s01_pWOZ_r03.png (writer=182, prompt=WOZ)
# File /workspace/Hand/original/w0182_s01_pWOZ_r03.png - FilteredLine 0: #론론론
# Processing: /workspace/Hand/original/w0184_s01_pWOZ_r03.png (writer=184, prompt=WOZ)
# File /workspace/Hand/original/w0184_s01_pWOZ_r03.png - FilteredLine 0: Wirinu" ctatttitrzilarr stars"iwwtr trtriy fmora Rtr ,
# Processing: /workspace/Hand/original/w0186_s01_pWOZ_r03.png (writer=186, prompt=WOZ)
# File /workspace/Hand/original/w0186_s01_pWOZ_r03.png - FilteredLine 0: 홀움?
# Processing: /workspace/Hand/original/w0189_s01_pWOZ_r03.png (writer=189, prompt=WOZ)
# File /workspace/Hand/original/w0189_s01_pWOZ_r03.png - FilteredLine 0: 표하 33;
# Processing: /workspace/Hand/original/w0191_s01_pWOZ_r03.png (writer=191, prompt=WOZ)
# File /workspace/Hand/original/w0191_s01_pWOZ_r03.png - FilteredLine 0: "하-`a 플:
# Processing: /workspace/Hand/original/w0193_s01_pWOZ_r03.png (writer=193, prompt=WOZ)
# File /workspace/Hand/original/w0193_s01_pWOZ_r03.png - FilteredLine 0: 소l출
# Processing: /workspace/Hand/original/w0198_s01_pWOZ_r03.png (writer=198, prompt=WOZ)
# File /workspace/Hand/original/w0198_s01_pWOZ_r03.png - FilteredLine 0: '   WinnaShoffmeSn Was Wallir9 bnzlu towvarzfre Emerald Cit'
# Processing: /workspace/Hand/original/w0199_s01_pWOZ_r03.png (writer=199, prompt=WOZ)
# File /workspace/Hand/original/w0199_s01_pWOZ_r03.png - FilteredLine 0: 발카로로로하교:
# Processing: /workspace/Hand/original/w0200_s01_pWOZ_r03.png (writer=200, prompt=WOZ)
# File /workspace/Hand/original/w0200_s01_pWOZ_r03.png - FilteredLine 0: '  Wphis 쇼 skof+ fipe Bk ilas (리Eiw} biyki faiad X (rrl Cry' k silir chae}
# Processing: /workspace/Hand/original/w0201_s01_pWOZ_r03.png (writer=201, prompt=WOZ)
# File /workspace/Hand/original/w0201_s01_pWOZ_r03.png - FilteredLine 0: 훈m쪽
# Processing: /workspace/Hand/original/w0202_s01_pWOZ_r03.png (writer=202, prompt=WOZ)
# File /workspace/Hand/original/w0202_s01_pWOZ_r03.png - FilteredLine 0: 탤륭록발출::
# Processing: /workspace/Hand/original/w0203_s01_pWOZ_r03.png (writer=203, prompt=WOZ)
# Processing: /workspace/Hand/original/w0204_s01_pWOZ_r03.png (writer=204, prompt=WOZ)
# File /workspace/Hand/original/w0204_s01_pWOZ_r03.png - FilteredLine 0: '  Nihin q shedt +ime She Nas walking   brukly +oward the Emcral Crty,
# Processing: /workspace/Hand/original/w0205_s01_pWOZ_r03.png (writer=205, prompt=WOZ)
# File /workspace/Hand/original/w0205_s01_pWOZ_r03.png - FilteredLine 0: ~%록 #R록
# Processing: /workspace/Hand/original/w0206_s01_pWOZ_r03.png (writer=206, prompt=WOZ)
# File /workspace/Hand/original/w0206_s01_pWOZ_r03.png - FilteredLine 0: 홀기
# Processing: /workspace/Hand/original/w0212_s01_pWOZ_r03.png (writer=212, prompt=WOZ)
# File /workspace/Hand/original/w0212_s01_pWOZ_r03.png - FilteredLine 0: Jrsnntitsapi `" @,Nrarsowan"
# Processing: /workspace/Hand/original/w0216_s01_pWOZ_r03.png (writer=216, prompt=WOZ)
# File /workspace/Hand/original/w0216_s01_pWOZ_r03.png - FilteredLine 0: 출론
# Processing: /workspace/Hand/original/w0218_s01_pWOZ_r03.png (writer=218, prompt=WOZ)
# File /workspace/Hand/original/w0218_s01_pWOZ_r03.png - FilteredLine 0:  I표"_%eiicgjin
# Processing: /workspace/Hand/original/w0220_s01_pWOZ_r03.png (writer=220, prompt=WOZ)
# File /workspace/Hand/original/w0220_s01_pWOZ_r03.png - FilteredLine 0: ' widw;n ( Sncrs Ainu  Siv lu} (uulrny borJF') jiavd (we Cnerw서l (;y7,
# Processing: /workspace/Hand/original/w0223_s01_pWOZ_r03.png (writer=223, prompt=WOZ)
# Processing: /workspace/Hand/original/w0224_s01_pWOZ_r03.png (writer=224, prompt=WOZ)
# File /workspace/Hand/original/w0224_s01_pWOZ_r03.png - FilteredLine 0: 훌 장
# Processing: /workspace/Hand/original/w0226_s01_pWOZ_r03.png (writer=226, prompt=WOZ)
# File /workspace/Hand/original/w0226_s01_pWOZ_r03.png - FilteredLine 0: e'rskir  되+" R"9wi; 015,nra
# Processing: /workspace/Hand/original/w0227_s01_pWOZ_r03.png (writer=227, prompt=WOZ)
# File /workspace/Hand/original/w0227_s01_pWOZ_r03.png - FilteredLine 0: 훌출출:
# Processing: /workspace/Hand/original/w0229_s01_pWOZ_r03.png (writer=229, prompt=WOZ)
# File /workspace/Hand/original/w0229_s01_pWOZ_r03.png - FilteredLine 0: 운훈움
# Processing: /workspace/Hand/original/w0232_s01_pWOZ_r03.png (writer=232, prompt=WOZ)
# File /workspace/Hand/original/w0232_s01_pWOZ_r03.png - FilteredLine 0: Wliw % skor} hv sk vas usalkwa brv디} fuard
# Processing: /workspace/Hand/original/w0233_s01_pWOZ_r03.png (writer=233, prompt=WOZ)
# Processing: /workspace/Hand/original/w0234_s01_pWOZ_r03.png (writer=234, prompt=WOZ)
# File /workspace/Hand/original/w0234_s01_pWOZ_r03.png - FilteredLine 0:   Within l O커} Hmf @W   W WIHIna bi:ly fiwwd  fl
# Processing: /workspace/Hand/original/w0238_s01_pWOZ_r03.png (writer=238, prompt=WOZ)
# File /workspace/Hand/original/w0238_s01_pWOZ_r03.png - FilteredLine 0: 출
# Processing: /workspace/Hand/original/w0239_s01_pWOZ_r03.png (writer=239, prompt=WOZ)
# File /workspace/Hand/original/w0239_s01_pWOZ_r03.png - FilteredLine 0: ' WIHhin G  Sho4+ hi  sku   WaS   WaIlno   Drisk(u
# Processing: /workspace/Hand/original/w0240_s01_pWOZ_r03.png (writer=240, prompt=WOZ)
# File /workspace/Hand/original/w0240_s01_pWOZ_r03.png - FilteredLine 0:   Ui+hA & 5Kov+ Hie 5he wi!  wallikg   brskly  +ouar
# Processing: /workspace/Hand/original/w0242_s01_pWOZ_r03.png (writer=242, prompt=WOZ)
# File /workspace/Hand/original/w0242_s01_pWOZ_r03.png - FilteredLine 0: ~훌륭루
# Processing: /workspace/Hand/original/w0244_s01_pWOZ_r03.png (writer=244, prompt=WOZ)
# File /workspace/Hand/original/w0244_s01_pWOZ_r03.png - FilteredLine 0: 훌업 #
# Processing: /workspace/Hand/original/w0245_s01_pWOZ_r03.png (writer=245, prompt=WOZ)
# File /workspace/Hand/original/w0245_s01_pWOZ_r03.png - FilteredLine 0: "불운 운하
# Processing: /workspace/Hand/original/w0246_s01_pWOZ_r03.png (writer=246, prompt=WOZ)
# Processing: /workspace/Hand/original/w0249_s01_pWOZ_r03.png (writer=249, prompt=WOZ)
# Processing: /workspace/Hand/original/w0254_s01_pWOZ_r03.png (writer=254, prompt=WOZ)
# File /workspace/Hand/original/w0254_s01_pWOZ_r03.png - FilteredLine 0: efvtkin rn Shaxtvticitsiir sivi 'iarssjnng Wrril]
# Processing: /workspace/Hand/original/w0255_s01_pWOZ_r03.png (writer=255, prompt=WOZ)
# File /workspace/Hand/original/w0255_s01_pWOZ_r03.png - FilteredLine 0: Cryncr Sivcr nonocrfvmsrwairrqi-orarafs fard ernicraid
# Processing: /workspace/Hand/original/w0260_s01_pWOZ_r03.png (writer=260, prompt=WOZ)
# File /workspace/Hand/original/w0260_s01_pWOZ_r03.png - FilteredLine 0:  4 모iwd C라s rnthri" {innsi "nid
# Processing: /workspace/Hand/original/w0261_s01_pWOZ_r03.png (writer=261, prompt=WOZ)
# File /workspace/Hand/original/w0261_s01_pWOZ_r03.png - FilteredLine 0: 모inow 0,A4*1"33h도 +a o} @ra r여
# Processing: /workspace/Hand/original/w0262_s01_pWOZ_r03.png (writer=262, prompt=WOZ)
# File /workspace/Hand/original/w0262_s01_pWOZ_r03.png - FilteredLine 0: #출 l론록철학
# Processing: /workspace/Hand/original/w0263_s01_pWOZ_r03.png (writer=263, prompt=WOZ)
# File /workspace/Hand/original/w0263_s01_pWOZ_r03.png - FilteredLine 0: ' U)iNun Qskoct +re sLeian uJo오Luiw9 br;ski Couooec
# Processing: /workspace/Hand/original/w0264_s01_pWOZ_r03.png (writer=264, prompt=WOZ)
# File /workspace/Hand/original/w0264_s01_pWOZ_r03.png - FilteredLine 0: '   Wi-io a shoc4 Hne She wns   walkios   brisklu +owaca
# Processing: /workspace/Hand/original/w0270_s01_pWOZ_r03.png (writer=270, prompt=WOZ)
# File /workspace/Hand/original/w0270_s01_pWOZ_r03.png - FilteredLine 0: #출-l탑
# Processing: /workspace/Hand/original/w0271_s01_pWOZ_r03.png (writer=271, prompt=WOZ)
# File /workspace/Hand/original/w0271_s01_pWOZ_r03.png - FilteredLine 0: #쨌
# Processing: /workspace/Hand/original/w0276_s01_pWOZ_r03.png (writer=276, prompt=WOZ)
# File /workspace/Hand/original/w0276_s01_pWOZ_r03.png - FilteredLine 0: #::
# Processing: /workspace/Hand/original/w0277_s01_pWOZ_r03.png (writer=277, prompt=WOZ)
# File /workspace/Hand/original/w0277_s01_pWOZ_r03.png - FilteredLine 0: 'lrsob prmi drpwunmikng  sniki
# Processing: /workspace/Hand/original/w0279_s01_pWOZ_r03.png (writer=279, prompt=WOZ)
# File /workspace/Hand/original/w0279_s01_pWOZ_r03.png - FilteredLine 0: 콤 륭족
# Processing: /workspace/Hand/original/w0280_s01_pWOZ_r03.png (writer=280, prompt=WOZ)
# File /workspace/Hand/original/w0280_s01_pWOZ_r03.png - FilteredLine 0: 불플굽?
# Processing: /workspace/Hand/original/w0281_s01_pWOZ_r03.png (writer=281, prompt=WOZ)
# File /workspace/Hand/original/w0281_s01_pWOZ_r03.png - FilteredLine 0: 콤:?%
# Processing: /workspace/Hand/original/w0282_s01_pWOZ_r03.png (writer=282, prompt=WOZ)
# File /workspace/Hand/original/w0282_s01_pWOZ_r03.png - FilteredLine 0: #다 31357 33333도"4 6im8 "
# Processing: /workspace/Hand/original/w0284_s01_pWOZ_r03.png (writer=284, prompt=WOZ)
# File /workspace/Hand/original/w0284_s01_pWOZ_r03.png - FilteredLine 0: B 심  7다
# Processing: /workspace/Hand/original/w0285_s01_pWOZ_r03.png (writer=285, prompt=WOZ)
# File /workspace/Hand/original/w0285_s01_pWOZ_r03.png - FilteredLine 0: '  Gmald Ciyi has slvu Jboes 4ntliy hril Ch Vu hard, Halbu
# Processing: /workspace/Hand/original/w0286_s01_pWOZ_r03.png (writer=286, prompt=WOZ)
# File /workspace/Hand/original/w0286_s01_pWOZ_r03.png - FilteredLine 0: m론
# Processing: /workspace/Hand/original/w0287_s01_pWOZ_r03.png (writer=287, prompt=WOZ)
# File /workspace/Hand/original/w0287_s01_pWOZ_r03.png - FilteredLine 0: 축출 ?
# Processing: /workspace/Hand/original/w0288_s01_pWOZ_r03.png (writer=288, prompt=WOZ)
# libpng warning: Incorrect bKGD chunk length
# File /workspace/Hand/original/w0288_s01_pWOZ_r03.png - FilteredLine 0:  Inif)   0 SYYNt TIYu `Il   WNOJ   WCUK(O) bXISCIL tuucuifa
# Processing: /workspace/Hand/original/w0289_s01_pWOZ_r03.png (writer=289, prompt=WOZ)
# File /workspace/Hand/original/w0289_s01_pWOZ_r03.png - FilteredLine 0: 록하요3
# Processing: /workspace/Hand/original/w0291_s01_pWOZ_r03.png (writer=291, prompt=WOZ)
# File /workspace/Hand/original/w0291_s01_pWOZ_r03.png - FilteredLine 0: 컴  _한하 하름다;포
# Processing: /workspace/Hand/original/w0293_s01_pWOZ_r03.png (writer=293, prompt=WOZ)
# File /workspace/Hand/original/w0293_s01_pWOZ_r03.png - FilteredLine 0: eotnsa 'd Nrlion fiea inaretnraes "rss
# Processing: /workspace/Hand/original/w0297_s01_pWOZ_r03.png (writer=297, prompt=WOZ)
# Processing: /workspace/Hand/original/w0299_s01_pWOZ_r03.png (writer=299, prompt=WOZ)
# File /workspace/Hand/original/w0299_s01_pWOZ_r03.png - FilteredLine 0:   (Aiw 0 SWorl liwe Ate Wtv)   Wxkinf briskk
# Processing: /workspace/Hand/original/w0301_s01_pWOZ_r03.png (writer=301, prompt=WOZ)
# File /workspace/Hand/original/w0301_s01_pWOZ_r03.png - FilteredLine 0: 면aori` siraai"ei
# Processing: /workspace/Hand/original/w0302_s01_pWOZ_r03.png (writer=302, prompt=WOZ)
# File /workspace/Hand/original/w0302_s01_pWOZ_r03.png - FilteredLine 0: #sl. t4wallrdlsrnlr ein s'ad sisiai sn "psss4
# Processing: /workspace/Hand/original/w0304_s01_pWOZ_r03.png (writer=304, prompt=WOZ)
# File /workspace/Hand/original/w0304_s01_pWOZ_r03.png - FilteredLine 0: '현로  하
# Processing: /workspace/Hand/original/w0305_s01_pWOZ_r03.png (writer=305, prompt=WOZ)
# File /workspace/Hand/original/w0305_s01_pWOZ_r03.png - FilteredLine 0: @기-:
# Processing: /workspace/Hand/original/w0306_s01_pWOZ_r03.png (writer=306, prompt=WOZ)
# File /workspace/Hand/original/w0306_s01_pWOZ_r03.png - FilteredLine 0: ki4" "2,rinrss' lsx"? d_#병sifioyini
# Processing: /workspace/Hand/original/w0308_s01_pWOZ_r03.png (writer=308, prompt=WOZ)
# File /workspace/Hand/original/w0308_s01_pWOZ_r03.png - FilteredLine 0: eWrnn "ahar nire Frimi ia-
# Processing: /workspace/Hand/original/w0312_s01_pWOZ_r03.png (writer=312, prompt=WOZ)
# File /workspace/Hand/original/w0312_s01_pWOZ_r03.png - FilteredLine 0: "콤B rn aaa가로
# Processing: /workspace/Hand/original/w0313_s01_pWOZ_r03.png (writer=313, prompt=WOZ)
# File /workspace/Hand/original/w0313_s01_pWOZ_r03.png - FilteredLine 0: 필_ 조금_#:_보_"름_하~
# Processing: /workspace/Hand/original/w0314_s01_pWOZ_r03.png (writer=314, prompt=WOZ)
# File /workspace/Hand/original/w0314_s01_pWOZ_r03.png - FilteredLine 0: '  Wfhin CShort +re she   W추   wrilkim9 briil (ward
# Processing: /workspace/Hand/original/w0315_s01_pWOZ_r03.png (writer=315, prompt=WOZ)
# File /workspace/Hand/original/w0315_s01_pWOZ_r03.png - FilteredLine 0: @혼l들:
# Processing: /workspace/Hand/original/w0317_s01_pWOZ_r3.png (writer=317, prompt=WOZ)
# libpng warning: Incorrect bKGD chunk length
# File /workspace/Hand/original/w0317_s01_pWOZ_r3.png - FilteredLine 0: 'dbn& sat five  Jle   kns"ngKy   tevnee
# Processing: /workspace/Hand/original/w0319_s01_pWOZ_r03.png (writer=319, prompt=WOZ)
# File /workspace/Hand/original/w0319_s01_pWOZ_r03.png - FilteredLine 0: #출훈쪽:
# Processing: /workspace/Hand/original/w0320_s01_pWOZ_r03.png (writer=320, prompt=WOZ)
# File /workspace/Hand/original/w0320_s01_pWOZ_r03.png - FilteredLine 0: ~ 히n; 조요
# Processing: /workspace/Hand/original/w0322_s01_pWOZ_r03.png (writer=322, prompt=WOZ)
# File /workspace/Hand/original/w0322_s01_pWOZ_r03.png - FilteredLine 0: "9 하다 ?
# Processing: /workspace/Hand/original/w0330_s01_pWOZ_r03.png (writer=330, prompt=WOZ)
# File /workspace/Hand/original/w0330_s01_pWOZ_r03.png - FilteredLine 0: 불
# Processing: /workspace/Hand/original/w0333_s01_pWOZ_r03.png (writer=333, prompt=WOZ)
# File /workspace/Hand/original/w0333_s01_pWOZ_r03.png - FilteredLine 0: e%x' ~ naro""ss" ~sf n; Aa *3 j*s 66rss in"s
# Processing: /workspace/Hand/original/w0334_s01_pWOZ_r03.png (writer=334, prompt=WOZ)
# File /workspace/Hand/original/w0334_s01_pWOZ_r03.png - FilteredLine 0: brs버y +wwa++anssrni Cis '"a1*3
# Processing: /workspace/Hand/original/w0335_s01_pWOZ_r03.png (writer=335, prompt=WOZ)
# File /workspace/Hand/original/w0335_s01_pWOZ_r03.png - FilteredLine 0: frmn"rnn"arnn"iys wn 'w wm" niann anas염m
# Processing: /workspace/Hand/original/w0337_s01_pWOZ_r03.png (writer=337, prompt=WOZ)
# File /workspace/Hand/original/w0337_s01_pWOZ_r03.png - FilteredLine 0: '  Wsir 45 Ks +im ss Ucs uukns brsiz   dvi d Srinj 여
# Processing: /workspace/Hand/original/w0338_s01_pWOZ_r03.png (writer=338, prompt=WOZ)
# File /workspace/Hand/original/w0338_s01_pWOZ_r03.png - FilteredLine 0: 조 다]다 nn messwn;
# Processing: /workspace/Hand/original/w0339_s01_pWOZ_r03.png (writer=339, prompt=WOZ)
# File /workspace/Hand/original/w0339_s01_pWOZ_r03.png - FilteredLine 0: '출론론월출
# Processing: /workspace/Hand/original/w0340_s01_pWOZ_r03.png (writer=340, prompt=WOZ)
# File /workspace/Hand/original/w0340_s01_pWOZ_r03.png - FilteredLine 0: tonnin "HfsnarEnrtirid ta Yancpaikia Eriskly
# Processing: /workspace/Hand/original/w0341_s01_pWOZ_r03.png (writer=341, prompt=WOZ)
# File /workspace/Hand/original/w0341_s01_pWOZ_r03.png - FilteredLine 0: 콤로로:
# Processing: /workspace/Hand/original/w0342_s01_pWOZ_r03.png (writer=342, prompt=WOZ)
# File /workspace/Hand/original/w0342_s01_pWOZ_r03.png - FilteredLine 0: eprnrsspassrnhras-pstattronriszi tayszietErzez (채
# Processing: /workspace/Hand/original/w0344_s01_pWOZ_r03.png (writer=344, prompt=WOZ)
# File /workspace/Hand/original/w0344_s01_pWOZ_r03.png - FilteredLine 0: ~ptitphuifoward"frt artnralwatinr
# Processing: /workspace/Hand/original/w0345_s01_pWOZ_r03.png (writer=345, prompt=WOZ)
# File /workspace/Hand/original/w0345_s01_pWOZ_r03.png - FilteredLine 0: 'w nuw pipi"ran"ni ouisdon" ruriAn VCinna pa"nar Fi
# Processing: /workspace/Hand/original/w0348_s01_pWOZ_r03.png (writer=348, prompt=WOZ)
# File /workspace/Hand/original/w0348_s01_pWOZ_r03.png - FilteredLine 0: 컴불_ #T도름 하중플#
# Processing: /workspace/Hand/original/w0350_s01_pWOZ_r03.png (writer=350, prompt=WOZ)
# File /workspace/Hand/original/w0350_s01_pWOZ_r03.png - FilteredLine 0:   WiAhiv a shovt Hwie sk was Waltp) bviskly >orian
# Processing: /workspace/Hand/original/w0351_s01_pWOZ_r03.png (writer=351, prompt=WOZ)
# File /workspace/Hand/original/w0351_s01_pWOZ_r03.png - FilteredLine 0: Dnwknli" Ch fa s#* "A' "ybrnrariifoin #
# Processing: /workspace/Hand/original/w0352_s01_pWOZ_r03.png (writer=352, prompt=WOZ)
# File /workspace/Hand/original/w0352_s01_pWOZ_r03.png - FilteredLine 0: 굵목표록 ,
# Processing: /workspace/Hand/original/w0353_s01_pWOZ_r03.png (writer=353, prompt=WOZ)
# File /workspace/Hand/original/w0353_s01_pWOZ_r03.png - FilteredLine 0: 모j"i;jm ptsn4 AwrtniiVian"ril ,aai * 6i
# Processing: /workspace/Hand/original/w0354_s01_pWOZ_r03.png (writer=354, prompt=WOZ)
# File /workspace/Hand/original/w0354_s01_pWOZ_r03.png - FilteredLine 0: ' Uithir c sha+ +iwie sk Las woluir DYsklu jaoqd
# Processing: /workspace/Hand/original/w0355_s01_pWOZ_r03.png (writer=355, prompt=WOZ)
# File /workspace/Hand/original/w0355_s01_pWOZ_r03.png - FilteredLine 0: 불히하오적공보"
# Processing: /workspace/Hand/original/w0356_s01_pWOZ_r03.png (writer=356, prompt=WOZ)
# File /workspace/Hand/original/w0356_s01_pWOZ_r03.png - FilteredLine 0: ' Within ( 5oye + ( yV7 she Ws walynq
# Processing: /workspace/Hand/original/w0357_s01_pWOZ_r03.png (writer=357, prompt=WOZ)
# File /workspace/Hand/original/w0357_s01_pWOZ_r03.png - FilteredLine 0: 돌?#?국
# Processing: /workspace/Hand/original/w0359_s01_pWOZ_r03.png (writer=359, prompt=WOZ)
# File /workspace/Hand/original/w0359_s01_pWOZ_r03.png - FilteredLine 0: ~품   국걱: 도움 .
# Processing: /workspace/Hand/original/w0362_s01_pWOZ_r03.png (writer=362, prompt=WOZ)
# File /workspace/Hand/original/w0362_s01_pWOZ_r03.png - FilteredLine 0: ' Wrhis & Short fne she uaf  walkiv bfisdy fward Hi Erer ald Cin , her silver Shoes
# Processing: /workspace/Hand/original/w0364_s01_pWOZ_r03.png (writer=364, prompt=WOZ)
# Processing: /workspace/Hand/original/w0365_s01_pWOZ_r03.png (writer=365, prompt=WOZ)
# File /workspace/Hand/original/w0365_s01_pWOZ_r03.png - FilteredLine 0: ~VixungrosiJo_fm'x Sigkuispoazilrif KLA"rorthru.
# Processing: /workspace/Hand/original/w0367_s01_pWOZ_r03.png (writer=367, prompt=WOZ)
# File /workspace/Hand/original/w0367_s01_pWOZ_r03.png - FilteredLine 0: ~콤:발표 P;37려
# Processing: /workspace/Hand/original/w0368_s01_pWOZ_r03.png (writer=368, prompt=WOZ)
# Processing: /workspace/Hand/original/w0370_s01_pWOZ_r03.png (writer=370, prompt=WOZ)
# File /workspace/Hand/original/w0370_s01_pWOZ_r03.png - FilteredLine 0:  탤도
# Processing: /workspace/Hand/original/w0371_s01_pWOZ_r03.png (writer=371, prompt=WOZ)
# File /workspace/Hand/original/w0371_s01_pWOZ_r03.png - FilteredLine 0: 또; 85
# Processing: /workspace/Hand/original/w0372_s01_pWOZ_r03.png (writer=372, prompt=WOZ)
# Processing: /workspace/Hand/original/w0375_s01_pWOZ_r03.png (writer=375, prompt=WOZ)
# File /workspace/Hand/original/w0375_s01_pWOZ_r03.png - FilteredLine 0: #동@
# Processing: /workspace/Hand/original/w0378_s01_pWOZ_r03.png (writer=378, prompt=WOZ)
# libpng warning: Incorrect bKGD chunk length
# File /workspace/Hand/original/w0378_s01_pWOZ_r03.png - FilteredLine 0: # 품국 품로 콤고
# Processing: /workspace/Hand/original/w0379_s01_pWOZ_r03.png (writer=379, prompt=WOZ)
# File /workspace/Hand/original/w0379_s01_pWOZ_r03.png - FilteredLine 0: 표골?
# Processing: /workspace/Hand/original/w0380_s01_pWOZ_r03.png (writer=380, prompt=WOZ)
# File /workspace/Hand/original/w0380_s01_pWOZ_r03.png - FilteredLine 0:  (Vithin  a Short fir Ska  usis ualkinq   bristl니 tcwadd
# Processing: /workspace/Hand/original/w0381_s01_pWOZ_r03.png (writer=381, prompt=WOZ)
# File /workspace/Hand/original/w0381_s01_pWOZ_r03.png - FilteredLine 0:  wk' "sit t고 AN wrs wrlpis   Nruin-torril
# Processing: /workspace/Hand/original/w0382_s01_pWOZ_r03.png (writer=382, prompt=WOZ)
# File /workspace/Hand/original/w0382_s01_pWOZ_r03.png - FilteredLine 0: ~WVIthin 0 shovt timt Sht Was Walkinq brisklu
# Processing: /workspace/Hand/original/w0383_s01_pWOZ_r03.png (writer=383, prompt=WOZ)
# File /workspace/Hand/original/w0383_s01_pWOZ_r03.png - FilteredLine 0:   Wifsis   cskir   fw 왜 wos   Jo-lwiv?   bysil   +uord
# Processing: /workspace/Hand/original/w0384_s01_pWOZ_r03.png (writer=384, prompt=WOZ)
# File /workspace/Hand/original/w0384_s01_pWOZ_r03.png - FilteredLine 0: 탤홀륭:
# Processing: /workspace/Hand/original/w0387_s01_pWOZ_r03.png (writer=387, prompt=WOZ)
# File /workspace/Hand/original/w0387_s01_pWOZ_r03.png - FilteredLine 0: "{a리하 있균;
# Processing: /workspace/Hand/original/w0388_s01_pWOZ_r03.png (writer=388, prompt=WOZ)
# File /workspace/Hand/original/w0388_s01_pWOZ_r03.png - FilteredLine 0: 'ropmara irirrnrsrwnns
# Processing: /workspace/Hand/original/w0391_s01_pWOZ_r03.png (writer=391, prompt=WOZ)
# File /workspace/Hand/original/w0391_s01_pWOZ_r03.png - FilteredLine 0: enarnerisiana' aran astrenns.
# Processing: /workspace/Hand/original/w0392_s01_pWOZ_r03.png (writer=392, prompt=WOZ)
# File /workspace/Hand/original/w0392_s01_pWOZ_r03.png - FilteredLine 0:  8i71 wxa 'ins' biini ssuddaiia 'hiitrs  wn} 0 %
# Processing: /workspace/Hand/original/w0393_s01_pWOZ_r03.png (writer=393, prompt=WOZ)
# File /workspace/Hand/original/w0393_s01_pWOZ_r03.png - FilteredLine 0:  표션로국표표표
# Processing: /workspace/Hand/original/w0394_s01_pWOZ_r03.png (writer=394, prompt=WOZ)
# File /workspace/Hand/original/w0394_s01_pWOZ_r03.png - FilteredLine 0: 돌론::
# Processing: /workspace/Hand/original/w0396_s01_pWOZ_r03.png (writer=396, prompt=WOZ)
# File /workspace/Hand/original/w0396_s01_pWOZ_r03.png - FilteredLine 0: ornaannanrinrararaa"
# Processing: /workspace/Hand/original/w0397_s01_pWOZ_r03.png (writer=397, prompt=WOZ)
# File /workspace/Hand/original/w0397_s01_pWOZ_r03.png - FilteredLine 0: ':적다훌름오도:표
# Processing: /workspace/Hand/original/w0398_s01_pWOZ_r03.png (writer=398, prompt=WOZ)
# File /workspace/Hand/original/w0398_s01_pWOZ_r03.png - FilteredLine 0: ' WiHhiv C short +iw ske WCis   walkivo briskly
# Processing: /workspace/Hand/original/w0399_s01_pWOZ_r03.png (writer=399, prompt=WOZ)
# File /workspace/Hand/original/w0399_s01_pWOZ_r03.png - FilteredLine 0: '고"그하하하요:
# Processing: /workspace/Hand/original/w0400_s01_pWOZ_r03.png (writer=400, prompt=WOZ)
# File /workspace/Hand/original/w0400_s01_pWOZ_r03.png - FilteredLine 0: 03317537 &
# Processing: /workspace/Hand/original/w0401_s01_pWOZ_r03.png (writer=401, prompt=WOZ)
# File /workspace/Hand/original/w0401_s01_pWOZ_r03.png - FilteredLine 0: ermn @" 3" ~A"다B다"% Jpais
# Processing: /workspace/Hand/original/w0402_s01_pWOZ_r03.png (writer=402, prompt=WOZ)
# Processing: /workspace/Hand/original/w0403_s01_pWOZ_r03.png (writer=403, prompt=WOZ)
# File /workspace/Hand/original/w0403_s01_pWOZ_r03.png - FilteredLine 0: ~하로하"3하
# Processing: /workspace/Hand/original/w0405_s01_pWOZ_r03.png (writer=405, prompt=WOZ)
# File /workspace/Hand/original/w0405_s01_pWOZ_r03.png - FilteredLine 0: Withirrqihsttiprrr waSec`
# Processing: /workspace/Hand/original/w0406_s01_pWOZ_r03.png (writer=406, prompt=WOZ)
# Processing: /workspace/Hand/original/w0407_s01_pWOZ_r03.png (writer=407, prompt=WOZ)
# File /workspace/Hand/original/w0407_s01_pWOZ_r03.png - FilteredLine 0: ~훈훈록:
# Processing: /workspace/Hand/original/w0408_s01_pWOZ_r03.png (writer=408, prompt=WOZ)
# File /workspace/Hand/original/w0408_s01_pWOZ_r03.png - FilteredLine 0: '  Within 4 Short tinl  8l Wa Wallinq briyly fowirrl {l
# Processing: /workspace/Hand/original/w0409_s01_pWOZ_r03.png (writer=409, prompt=WOZ)
# File /workspace/Hand/original/w0409_s01_pWOZ_r03.png - FilteredLine 0: Witlr R  Swr+tiw Si wao walkiig} lni8izl4
# Processing: /workspace/Hand/original/w0410_s01_pWOZ_r03.png (writer=410, prompt=WOZ)
# Processing: /workspace/Hand/original/w0411_s01_pWOZ_r03.png (writer=411, prompt=WOZ)
# File /workspace/Hand/original/w0411_s01_pWOZ_r03.png - FilteredLine 0:  불하다다움문플 히렉로
# Processing: /workspace/Hand/original/w0412_s01_pWOZ_r03.png (writer=412, prompt=WOZ)
# File /workspace/Hand/original/w0412_s01_pWOZ_r03.png - FilteredLine 0: 훈출:
# Processing: /workspace/Hand/original/w0413_s01_pWOZ_r03.png (writer=413, prompt=WOZ)
# File /workspace/Hand/original/w0413_s01_pWOZ_r03.png - FilteredLine 0: twata Trrfpilatlirhiizitiuzr rodvid, 가
# Processing: /workspace/Hand/original/w0414_s01_pWOZ_r03.png (writer=414, prompt=WOZ)
# File /workspace/Hand/original/w0414_s01_pWOZ_r03.png - FilteredLine 0: ; 3; 지하하:
# Processing: /workspace/Hand/original/w0415_s01_pWOZ_r03.png (writer=415, prompt=WOZ)
# File /workspace/Hand/original/w0415_s01_pWOZ_r03.png - FilteredLine 0:  P)Hhm 닦 Bhoy Sr ahe Lao uoaQEin) borsly
# Processing: /workspace/Hand/original/w0416_s01_pWOZ_r03.png (writer=416, prompt=WOZ)
# File /workspace/Hand/original/w0416_s01_pWOZ_r03.png - FilteredLine 0: 콤목홀:
# Processing: /workspace/Hand/original/w0417_s01_pWOZ_r03.png (writer=417, prompt=WOZ)
# File /workspace/Hand/original/w0417_s01_pWOZ_r03.png - FilteredLine 0: 콤표로표국
# Processing: /workspace/Hand/original/w0418_s01_pWOZ_r03.png (writer=418, prompt=WOZ)
# File /workspace/Hand/original/w0418_s01_pWOZ_r03.png - FilteredLine 0: 품기뒷n품
# Processing: /workspace/Hand/original/w0419_s01_pWOZ_r03.png (writer=419, prompt=WOZ)
# File /workspace/Hand/original/w0419_s01_pWOZ_r03.png - FilteredLine 0: 하";: "7 ""3"a배님} 틀""
# Processing: /workspace/Hand/original/w0420_s01_pWOZ_r03.png (writer=420, prompt=WOZ)
# File /workspace/Hand/original/w0420_s01_pWOZ_r03.png - FilteredLine 0: ' Uifuin C Ahoft   hr Sht waswcing   brill   fuaia
# Processing: /workspace/Hand/original/w0422_s01_pWOZ_r03.png (writer=422, prompt=WOZ)
# File /workspace/Hand/original/w0422_s01_pWOZ_r03.png - FilteredLine 0: '뭄록록
# Processing: /workspace/Hand/original/w0424_s01_pWOZ_r03.png (writer=424, prompt=WOZ)
# File /workspace/Hand/original/w0424_s01_pWOZ_r03.png - FilteredLine 0: ' Wtki   C   {hort   tine   ihe   waS   (aliiy]   모디디   tad
# Processing: /workspace/Hand/original/w0425_s01_pWOZ_r03.png (writer=425, prompt=WOZ)
# File /workspace/Hand/original/w0425_s01_pWOZ_r03.png - FilteredLine 0: "출로하포몸;
# Processing: /workspace/Hand/original/w0426_s01_pWOZ_r03.png (writer=426, prompt=WOZ)
# File /workspace/Hand/original/w0426_s01_pWOZ_r03.png - FilteredLine 0: 훌
# Processing: /workspace/Hand/original/w0428_s01_pWOZ_r03.png (writer=428, prompt=WOZ)
# File /workspace/Hand/original/w0428_s01_pWOZ_r03.png - FilteredLine 0: ~wn 'Untriitrsfwk" jws ;N} '"}} o"#h들d
# Processing: /workspace/Hand/original/w0429_s01_pWOZ_r03.png (writer=429, prompt=WOZ)
# File /workspace/Hand/original/w0429_s01_pWOZ_r03.png - FilteredLine 0:  +owwdvi ossri+ Irn'KSP' si" sixstspnAbnsti]
# Processing: /workspace/Hand/original/w0431_s01_pWOZ_r03.png (writer=431, prompt=WOZ)
# File /workspace/Hand/original/w0431_s01_pWOZ_r03.png - FilteredLine 0: 굵준 @록물
# Processing: /workspace/Hand/original/w0433_s01_pWOZ_r03.png (writer=433, prompt=WOZ)
# File /workspace/Hand/original/w0433_s01_pWOZ_r03.png - FilteredLine 0: 소
# Processing: /workspace/Hand/original/w0435_s01_pWOZ_r03.png (writer=435, prompt=WOZ)
# File /workspace/Hand/original/w0435_s01_pWOZ_r03.png - FilteredLine 0: 소터  톤:
# Processing: /workspace/Hand/original/w0436_s01_pWOZ_r03.png (writer=436, prompt=WOZ)
# Processing: /workspace/Hand/original/w0439_s01_pWOZ_r03.png (writer=439, prompt=WOZ)
# File /workspace/Hand/original/w0439_s01_pWOZ_r03.png - FilteredLine 0: eotre harrdnseiots roadledeTi j"
# Processing: /workspace/Hand/original/w0440_s01_pWOZ_r03.png (writer=440, prompt=WOZ)
# File /workspace/Hand/original/w0440_s01_pWOZ_r03.png - FilteredLine 0: wf +owaorttksnrsaa "aitijvaikinaivr
# Processing: /workspace/Hand/original/w0441_s01_pWOZ_r03.png (writer=441, prompt=WOZ)
# File /workspace/Hand/original/w0441_s01_pWOZ_r03.png - FilteredLine 0: "# 'Y0 hr31"",4"0 6w"! 많 rll i' 선 ,o4
# Processing: /workspace/Hand/original/w0443_s01_pWOZ_r03.png (writer=443, prompt=WOZ)
# File /workspace/Hand/original/w0443_s01_pWOZ_r03.png - FilteredLine 0: '  WlMiV   C SHUV  HV  SH W lis UUU IMC   VMASU(U
# Processing: /workspace/Hand/original/w0444_s01_pWOZ_r03.png (writer=444, prompt=WOZ)
# Processing: /workspace/Hand/original/w0445_s01_pWOZ_r03.png (writer=445, prompt=WOZ)
# File /workspace/Hand/original/w0445_s01_pWOZ_r03.png - FilteredLine 0: r noooawoaan"aspanpni ang
# Processing: /workspace/Hand/original/w0446_s01_pWOZ_r03.png (writer=446, prompt=WOZ)
# File /workspace/Hand/original/w0446_s01_pWOZ_r03.png - FilteredLine 0: #륭론국넉
# Processing: /workspace/Hand/original/w0448_s01_pWOZ_r03.png (writer=448, prompt=WOZ)
# File /workspace/Hand/original/w0448_s01_pWOZ_r03.png - FilteredLine 0: #d{nixtrans 5ax7 Biyit "i하674JX Rint
# Processing: /workspace/Hand/original/w0450_s01_pWOZ_r03.png (writer=450, prompt=WOZ)
# File /workspace/Hand/original/w0450_s01_pWOZ_r03.png - FilteredLine 0: 탤@국록
# Processing: /workspace/Hand/original/w0451_s01_pWOZ_r03.png (writer=451, prompt=WOZ)
# File /workspace/Hand/original/w0451_s01_pWOZ_r03.png - FilteredLine 0: nnis 'i'p*inssrsssixs Sran}iwirna" #*"
# Processing: /workspace/Hand/original/w0452_s01_pWOZ_r03.png (writer=452, prompt=WOZ)
# File /workspace/Hand/original/w0452_s01_pWOZ_r03.png - FilteredLine 0: 풀@활
# Processing: /workspace/Hand/original/w0453_s01_pWOZ_r03.png (writer=453, prompt=WOZ)
# File /workspace/Hand/original/w0453_s01_pWOZ_r03.png - FilteredLine 0: '  Witk 쇼 6ht +nee 6hc D5   kolkn Dnak
# Processing: /workspace/Hand/original/w0454_s01_pWOZ_r03.png (writer=454, prompt=WOZ)
# File /workspace/Hand/original/w0454_s01_pWOZ_r03.png - FilteredLine 0: 불대맥i표로-
# Processing: /workspace/Hand/original/w0456_s01_pWOZ_r03.png (writer=456, prompt=WOZ)
# File /workspace/Hand/original/w0456_s01_pWOZ_r03.png - FilteredLine 0: (Vidhn 대 Shal4 Jrmne She {as (uqlbiy brsk9   Jsiaml dhe
# Processing: /workspace/Hand/original/w0458_s01_pWOZ_r03.png (writer=458, prompt=WOZ)
# File /workspace/Hand/original/w0458_s01_pWOZ_r03.png - FilteredLine 0: 훈-
# Processing: /workspace/Hand/original/w0459_s01_pWOZ_r03.png (writer=459, prompt=WOZ)
# Processing: /workspace/Hand/original/w0460_s01_pWOZ_r03.png (writer=460, prompt=WOZ)
# File /workspace/Hand/original/w0460_s01_pWOZ_r03.png - FilteredLine 0:   W;Hkin & skc4 +iwe she ias ualkiwg   br;skld +oward
# Processing: /workspace/Hand/original/w0462_s01_pWOZ_r03.png (writer=462, prompt=WOZ)
# File /workspace/Hand/original/w0462_s01_pWOZ_r03.png - FilteredLine 0: ' "sny "oi ripazd , ioruizicaiacz sscza iirAig'
# Processing: /workspace/Hand/original/w0463_s01_pWOZ_r03.png (writer=463, prompt=WOZ)
# File /workspace/Hand/original/w0463_s01_pWOZ_r03.png - FilteredLine 0: rnini ondstii hsdajpalana rsaatird,ni Beroris"
# Processing: /workspace/Hand/original/w0464_s01_pWOZ_r03.png (writer=464, prompt=WOZ)
# ...
# File /workspace/Hand/original/w0595_s01_pWOZ_r03.png - FilteredLine 0:  Wthtera hhartAhns cerris oralrierrviins "rifioiiiaaidoid 뉴wisana Crn'
# Processing: /workspace/Hand/original/w0596_s01_pWOZ_r03.png (writer=596, prompt=WOZ)
# File /workspace/Hand/original/w0596_s01_pWOZ_r03.png - FilteredLine 0: :홀물로
# Processing: /workspace/Hand/original/w0597_s01_pWOZ_r03.png (writer=597, prompt=WOZ)
# File /workspace/Hand/original/w0597_s01_pWOZ_r03.png - FilteredLine 0: 물쳐볶물론:
# Processing: /workspace/Hand/original/w0598_s01_pWOZ_r03.png (writer=598, prompt=WOZ)
# File /workspace/Hand/original/w0598_s01_pWOZ_r03.png - FilteredLine 0: oaa uni" uap "" No p" s"면w"
# Processing: /workspace/Hand/original/w0599_s01_pWOZ_r03.png (writer=599, prompt=WOZ)
# File /workspace/Hand/original/w0599_s01_pWOZ_r03.png - FilteredLine 0: r 이움
# Processing: /workspace/Hand/original/w0600_s01_pWOZ_r03.png (writer=600, prompt=WOZ)
# File /workspace/Hand/original/w0600_s01_pWOZ_r03.png - FilteredLine 0: '  (uthir c Srt Hn ske bis wzlki)
# Processing: /workspace/Hand/original/w0601_s01_pWOZ_r03.png (writer=601, prompt=WOZ)
# File /workspace/Hand/original/w0601_s01_pWOZ_r03.png - FilteredLine 0: *an) _"rnji ingjtt"ist jpilds rasdtaiad
# Processing: /workspace/Hand/original/w0602_s01_pWOZ_r03.png (writer=602, prompt=WOZ)
# File /workspace/Hand/original/w0602_s01_pWOZ_r03.png - FilteredLine 0: 품론로다
# Processing: /workspace/Hand/original/w0604_s01_pWOZ_r03.png (writer=604, prompt=WOZ)
# File /workspace/Hand/original/w0604_s01_pWOZ_r03.png - FilteredLine 0:   UU;is < sva사 +;rr2 sVe (Das wa스a
# Processing: /workspace/Hand/original/w0605_s01_pWOZ_r03.png (writer=605, prompt=WOZ)
# File /workspace/Hand/original/w0605_s01_pWOZ_r03.png - FilteredLine 0: 모e,atia sn pAnahnst ririrei
# Processing: /workspace/Hand/original/w0606_s01_pWOZ_r03.png (writer=606, prompt=WOZ)
# Processing: /workspace/Hand/original/w0611_s01_pWOZ_r03.png (writer=611, prompt=WOZ)
# File /workspace/Hand/original/w0611_s01_pWOZ_r03.png - FilteredLine 0: 콤표로록:
# Processing: /workspace/Hand/original/w0612_s01_pWOZ_r03.png (writer=612, prompt=WOZ)
# File /workspace/Hand/original/w0612_s01_pWOZ_r03.png - FilteredLine 0: #i
# Processing: /workspace/Hand/original/w0613_s01_pWOZ_r03.png (writer=613, prompt=WOZ)
# File /workspace/Hand/original/w0613_s01_pWOZ_r03.png - FilteredLine 0: 명편끗 ;공얼국:
# Processing: /workspace/Hand/original/w0615_s01_pWOZ_r03.png (writer=615, prompt=WOZ)
# File /workspace/Hand/original/w0615_s01_pWOZ_r03.png - FilteredLine 0: 78
# Processing: /workspace/Hand/original/w0617_s01_pWOZ_r03.png (writer=617, prompt=WOZ)
# File /workspace/Hand/original/w0617_s01_pWOZ_r03.png - FilteredLine 0: 룹
# Processing: /workspace/Hand/original/w0618_s01_pWOZ_r03.png (writer=618, prompt=WOZ)
# File /workspace/Hand/original/w0618_s01_pWOZ_r03.png - FilteredLine 0:  waly itrcwitsii
# Processing: /workspace/Hand/original/w0619_s01_pWOZ_r03.png (writer=619, prompt=WOZ)
# File /workspace/Hand/original/w0619_s01_pWOZ_r03.png - FilteredLine 0: :
# Processing: /workspace/Hand/original/w0620_s01_pWOZ_r03.png (writer=620, prompt=WOZ)
# File /workspace/Hand/original/w0620_s01_pWOZ_r03.png - FilteredLine 0:  fke Exeratd Gt'ker S;ler   Skaes finkling "crril on trc
# Processing: /workspace/Hand/original/w0621_s01_pWOZ_r03.png (writer=621, prompt=WOZ)
# Processing: /workspace/Hand/original/w0622_s01_pWOZ_r03.png (writer=622, prompt=WOZ)
# File /workspace/Hand/original/w0622_s01_pWOZ_r03.png - FilteredLine 0: @}
# Processing: /workspace/Hand/original/w0623_s01_pWOZ_r03.png (writer=623, prompt=WOZ)
# File /workspace/Hand/original/w0623_s01_pWOZ_r03.png - FilteredLine 0: Wi a yiel ;m Sw Wk5 walhd} bnsk0   fnarls /a Cmrll(
# Processing: /workspace/Hand/original/w0624_s01_pWOZ_r03.png (writer=624, prompt=WOZ)
# File /workspace/Hand/original/w0624_s01_pWOZ_r03.png - FilteredLine 0: 골:
# Processing: /workspace/Hand/original/w0626_s01_pWOZ_r03.png (writer=626, prompt=WOZ)
# File /workspace/Hand/original/w0626_s01_pWOZ_r03.png - FilteredLine 0: ~Li4hiv 4 jkov+ ,ne Jk U0s Lalkiv9 brislclu
# Processing: /workspace/Hand/original/w0627_s01_pWOZ_r03.png (writer=627, prompt=WOZ)
# File /workspace/Hand/original/w0627_s01_pWOZ_r03.png - FilteredLine 0: "";'옷불m3요
# Processing: /workspace/Hand/original/w0628_s01_pWOZ_r03.png (writer=628, prompt=WOZ)
# File /workspace/Hand/original/w0628_s01_pWOZ_r03.png - FilteredLine 0: ~Diffwla Xwiorintiz skmilurci"Yac
# Processing: /workspace/Hand/original/w0629_s01_pWOZ_r03.png (writer=629, prompt=WOZ)
# File /workspace/Hand/original/w0629_s01_pWOZ_r03.png - FilteredLine 0: #로l"
# Processing: /workspace/Hand/original/w0630_s01_pWOZ_r03.png (writer=630, prompt=WOZ)
# File /workspace/Hand/original/w0630_s01_pWOZ_r03.png - FilteredLine 0: 풀:
# Processing: /workspace/Hand/original/w0632_s01_pWOZ_r03.png (writer=632, prompt=WOZ)
# File /workspace/Hand/original/w0632_s01_pWOZ_r03.png - FilteredLine 0: 훌장출
# Processing: /workspace/Hand/original/w0634_s01_pWOZ_r03.png (writer=634, prompt=WOZ)
# File /workspace/Hand/original/w0634_s01_pWOZ_r03.png - FilteredLine 0: 탤기록:
# Processing: /workspace/Hand/original/w0636_s01_pWOZ_r03.png (writer=636, prompt=WOZ)
# File /workspace/Hand/original/w0636_s01_pWOZ_r03.png - FilteredLine 0: usikwin C ontr+ }mc   Sl< Ucy) ujelli'n니 briskl니
# Processing: /workspace/Hand/original/w0637_s01_pWOZ_r03.png (writer=637, prompt=WOZ)
# File /workspace/Hand/original/w0637_s01_pWOZ_r03.png - FilteredLine 0: ~I사;4hi  qshil  hme sht U4s Hillinu brsily ;oird
# Processing: /workspace/Hand/original/w0638_s01_pWOZ_r03.png (writer=638, prompt=WOZ)
# File /workspace/Hand/original/w0638_s01_pWOZ_r03.png - FilteredLine 0: 효문감 구럽모 무}
# Processing: /workspace/Hand/original/w0639_s01_pWOZ_r03.png (writer=639, prompt=WOZ)
# File /workspace/Hand/original/w0639_s01_pWOZ_r03.png - FilteredLine 0: #arnnirpnannananyan.
# Processing: /workspace/Hand/original/w0640_s01_pWOZ_r03.png (writer=640, prompt=WOZ)
# libpng warning: Incorrect bKGD chunk length
# libpng warning: Incorrect bKGD chunk length
# File /workspace/Hand/original/w0640_s01_pWOZ_r03.png - FilteredLine 0: 표` 하;한름름
# Processing: /workspace/Hand/original/w0641_s01_pWOZ_r03.png (writer=641, prompt=WOZ)
# Processing: /workspace/Hand/original/w0642_s01_pWOZ_r03.png (writer=642, prompt=WOZ)
# Processing: /workspace/Hand/original/w0644_s01_pWOZ_r03.png (writer=644, prompt=WOZ)
# File /workspace/Hand/original/w0644_s01_pWOZ_r03.png - FilteredLine 0: Wilhin ^ shor}   +Ime   She   WAS  Wzlkin9
# Processing: /workspace/Hand/original/w0645_s01_pWOZ_r03.png (writer=645, prompt=WOZ)
# File /workspace/Hand/original/w0645_s01_pWOZ_r03.png - FilteredLine 0:   Win CN Skoc+ +we 8he Las
# Processing: /workspace/Hand/original/w0646_s01_pWOZ_r03.png (writer=646, prompt=WOZ)
# File /workspace/Hand/original/w0646_s01_pWOZ_r03.png - FilteredLine 0: qiKesnWz#, trr #; 5 "i bn}yt" "
# Processing: /workspace/Hand/original/w0647_s01_pWOZ_r03.png (writer=647, prompt=WOZ)
# File /workspace/Hand/original/w0647_s01_pWOZ_r03.png - FilteredLine 0: ~Uxlhn @ ShcfYwe Ska uns (nltiy Irskiq
# Processing: /workspace/Hand/original/w0648_s01_pWOZ_r03.png (writer=648, prompt=WOZ)
# File /workspace/Hand/original/w0648_s01_pWOZ_r03.png - FilteredLine 0: 학쪽
# Processing: /workspace/Hand/original/w0650_s01_pWOZ_r03.png (writer=650, prompt=WOZ)
# File /workspace/Hand/original/w0650_s01_pWOZ_r03.png - FilteredLine 0: be?n   Sudd enlw  Whisked  Rwo억 trim he 0wn Cowntri}   and
# Processing: /workspace/Hand/original/w0653_s01_pWOZ_r03.png (writer=653, prompt=WOZ)
# File /workspace/Hand/original/w0653_s01_pWOZ_r03.png - FilteredLine 0: @론움
# Processing: /workspace/Hand/original/w0656_s01_pWOZ_r03.png (writer=656, prompt=WOZ)
# File /workspace/Hand/original/w0656_s01_pWOZ_r03.png - FilteredLine 0: ittnafgherHineshewa"' shaliiAhkiirsYafori"na #rae
# Processing: /workspace/Hand/original/w0657_s01_pWOZ_r03.png (writer=657, prompt=WOZ)
# File /workspace/Hand/original/w0657_s01_pWOZ_r03.png - FilteredLine 0: Il나~~Q 8LiAJz sLur (cllu3 Prilba
# Processing: /workspace/Hand/original/w0658_s01_pWOZ_r03.png (writer=658, prompt=WOZ)
# File /workspace/Hand/original/w0658_s01_pWOZ_r03.png - FilteredLine 0: WrTzs*AEtaa_e EreanEotrrzn< 3X3+34  nzy
# Processing: /workspace/Hand/original/w0660_s01_pWOZ_r03.png (writer=660, prompt=WOZ)
# File /workspace/Hand/original/w0660_s01_pWOZ_r03.png - FilteredLine 0:  Ui+hin 9 Shon+ +ime She LaS (a니nq brisrlu +ouoYd +ne
# Processing: /workspace/Hand/original/w0661_s01_pWOZ_r03.png (writer=661, prompt=WOZ)
# File /workspace/Hand/original/w0661_s01_pWOZ_r03.png - FilteredLine 0: enn % @a다 IIa' ni nannmrarnms
# Processing: /workspace/Hand/original/w0662_s01_pWOZ_r03.png (writer=662, prompt=WOZ)
# File /workspace/Hand/original/w0662_s01_pWOZ_r03.png - FilteredLine 0: #교교:
# Processing: /workspace/Hand/original/w0664_s01_pWOZ_r03.png (writer=664, prompt=WOZ)
# File /workspace/Hand/original/w0664_s01_pWOZ_r03.png - FilteredLine 0: ern o"oinsna |ounsnen sinown trin"y
# Processing: /workspace/Hand/original/w0665_s01_pWOZ_r03.png (writer=665, prompt=WOZ)
# File /workspace/Hand/original/w0665_s01_pWOZ_r03.png - FilteredLine 0: rfp sls a' bd siuasbrisstittiyizeniiblj rand
# Processing: /workspace/Hand/original/w0666_s01_pWOZ_r03.png (writer=666, prompt=WOZ)
# File /workspace/Hand/original/w0666_s01_pWOZ_r03.png - FilteredLine 0: ~I,7s A SMa-Tine SKe [A wpkrb SeisrY
# Processing: /workspace/Hand/original/w0667_s01_pWOZ_r03.png (writer=667, prompt=WOZ)
# File /workspace/Hand/original/w0667_s01_pWOZ_r03.png - FilteredLine 0: 훌출:
# Processing: /workspace/Hand/original/w0668_s01_pWOZ_r03.png (writer=668, prompt=WOZ)
# File /workspace/Hand/original/w0668_s01_pWOZ_r03.png - FilteredLine 0: 국문
# Processing: /workspace/Hand/original/w0669_s01_pWOZ_r03.png (writer=669, prompt=WOZ)
# File /workspace/Hand/original/w0669_s01_pWOZ_r03.png - FilteredLine 0: 효자?
# Processing: /workspace/Hand/original/w0670_s01_pWOZ_r03.png (writer=670, prompt=WOZ)
# File /workspace/Hand/original/w0670_s01_pWOZ_r03.png - FilteredLine 0: ' 7 (Dull Luho hcicl  보liw Svclclaity  (vnisklcl
# Processing: /workspace/Hand/original/w0671_s01_pWOZ_r03.png (writer=671, prompt=WOZ)
# File /workspace/Hand/original/w0671_s01_pWOZ_r03.png - FilteredLine 0: '불n하" ;름수어:
# Processing: /workspace/Hand/original/w0673_s01_pWOZ_r03.png (writer=673, prompt=WOZ)
# File /workspace/Hand/original/w0673_s01_pWOZ_r03.png - FilteredLine 0: 불 로불-
# Processing: /workspace/Hand/original/w0674_s01_pWOZ_r03.png (writer=674, prompt=WOZ)
# Processing: /workspace/Hand/original/w0675_s01_pWOZ_r03.png (writer=675, prompt=WOZ)
# Processing: /workspace/Hand/original/w0677_s01_pWOZ_r03.png (writer=677, prompt=WOZ)
# File /workspace/Hand/original/w0677_s01_pWOZ_r03.png - FilteredLine 0: 훌l:
# Processing: /workspace/Hand/original/w0678_s01_pWOZ_r03.png (writer=678, prompt=WOZ)
# File /workspace/Hand/original/w0678_s01_pWOZ_r03.png - FilteredLine 0: rriaii nriirasrti"'
# Processing: /workspace/Hand/original/w0679_s01_pWOZ_r03.png (writer=679, prompt=WOZ)
# File /workspace/Hand/original/w0679_s01_pWOZ_r03.png - FilteredLine 0: ~xard "raoEmerotd shfyihetstiirg hossilg
# Processing: /workspace/Hand/original/w0680_s01_pWOZ_r03.png (writer=680, prompt=WOZ)
# File /workspace/Hand/original/w0680_s01_pWOZ_r03.png - FilteredLine 0: #n문흡
# Processing: /workspace/Hand/original/w0682_s01_pWOZ_r03.png (writer=682, prompt=WOZ)
# File /workspace/Hand/original/w0682_s01_pWOZ_r03.png - FilteredLine 0: Uilhis  R  shork Hioi sh vvas ualk;s   briskly
# Processing: /workspace/Hand/original/w0683_s01_pWOZ_r03.png (writer=683, prompt=WOZ)
# File /workspace/Hand/original/w0683_s01_pWOZ_r03.png - FilteredLine 0: ~W i{rik w   short   hni   Shl   waS   walki/
# Processing: /workspace/Hand/original/w0685_s01_pWOZ_r03.png (writer=685, prompt=WOZ)
# File /workspace/Hand/original/w0685_s01_pWOZ_r03.png - FilteredLine 0: 돌:
# Processing: /workspace/Hand/original/w0688_s01_pWOZ_r03.png (writer=688, prompt=WOZ)
# File /workspace/Hand/original/w0688_s01_pWOZ_r03.png - FilteredLine 0: 커출n자
# Processing: /workspace/Hand/original/w0691_s01_pWOZ_r03.png (writer=691, prompt=WOZ)
# File /workspace/Hand/original/w0691_s01_pWOZ_r03.png - FilteredLine 0: Wilhin d sho+ fimne   she  was   Walking
# Processing: /workspace/Hand/original/w0692_s01_pWOZ_r03.png (writer=692, prompt=WOZ)
# File /workspace/Hand/original/w0692_s01_pWOZ_r03.png - FilteredLine 0:   Wihih Q   Shov4 Ive   Sk   UCJ   Wcl([가s
# Processing: /workspace/Hand/original/w0693_s01_pWOZ_r03.png (writer=693, prompt=WOZ)
# File /workspace/Hand/original/w0693_s01_pWOZ_r03.png - FilteredLine 0:  bJ"; 름 "niasl y)`
# Processing: /workspace/Hand/original/w0694_s01_pWOZ_r03.png (writer=694, prompt=WOZ)
# Processing: /workspace/Hand/original/w0695_s01_pWOZ_r03.png (writer=695, prompt=WOZ)
# File /workspace/Hand/original/w0695_s01_pWOZ_r03.png - FilteredLine 0: 얼문
# Processing: /workspace/Hand/original/w0698_s01_pWOZ_r03.png (writer=698, prompt=WOZ)
# File /workspace/Hand/original/w0698_s01_pWOZ_r03.png - FilteredLine 0: #자-탓-하
# Processing: /workspace/Hand/original/w0699_s01_pWOZ_r03.png (writer=699, prompt=WOZ)
# File /workspace/Hand/original/w0699_s01_pWOZ_r03.png - FilteredLine 0: 훈기
# Processing: /workspace/Hand/original/w0700_s01_pWOZ_r03.png (writer=700, prompt=WOZ)
# File /workspace/Hand/original/w0700_s01_pWOZ_r03.png - FilteredLine 0: #&;
# Processing: /workspace/Hand/original/w0701_s01_pWOZ_r03.png (writer=701, prompt=WOZ)
# File /workspace/Hand/original/w0701_s01_pWOZ_r03.png - FilteredLine 0:  m; arxssiCpraifsa rB""8
# Processing: /workspace/Hand/original/w0702_s01_pWOZ_r03.png (writer=702, prompt=WOZ)
# File /workspace/Hand/original/w0702_s01_pWOZ_r03.png - FilteredLine 0: 물론출기
# Processing: /workspace/Hand/original/w0703_s01_pWOZ_r03.png (writer=703, prompt=WOZ)
# File /workspace/Hand/original/w0703_s01_pWOZ_r03.png - FilteredLine 0: 훌론로
# Processing: /workspace/Hand/original/w0704_s01_pWOZ_r03.png (writer=704, prompt=WOZ)
# File /workspace/Hand/original/w0704_s01_pWOZ_r03.png - FilteredLine 0:  Withiw   c Shoft   Einc CGS   (oalking
# Processing: /workspace/Hand/original/w0705_s01_pWOZ_r03.png (writer=705, prompt=WOZ)
# File /workspace/Hand/original/w0705_s01_pWOZ_r03.png - FilteredLine 0: 출
# Processing: /workspace/Hand/original/w0706_s01_pWOZ_r03.png (writer=706, prompt=WOZ)
# File /workspace/Hand/original/w0706_s01_pWOZ_r03.png - FilteredLine 0: Withn  h Skirt HN  She Ua5   Wukiwi briski나 furrd
# Processing: /workspace/Hand/original/w0707_s01_pWOZ_r03.png (writer=707, prompt=WOZ)
# File /workspace/Hand/original/w0707_s01_pWOZ_r03.png - FilteredLine 0: 15985
# Processing: /workspace/Hand/original/w0709_s01_pWOZ_r03.png (writer=709, prompt=WOZ)
# File /workspace/Hand/original/w0709_s01_pWOZ_r03.png - FilteredLine 0: 표로흐로}로
# Processing: /workspace/Hand/original/w0710_s01_pWOZ_r03.png (writer=710, prompt=WOZ)
# File /workspace/Hand/original/w0710_s01_pWOZ_r03.png - FilteredLine 0: 지대국;
# Processing: /workspace/Hand/original/w0711_s01_pWOZ_r03.png (writer=711, prompt=WOZ)
# File /workspace/Hand/original/w0711_s01_pWOZ_r03.png - FilteredLine 0: en @x ~ "  " ];
# Processing: /workspace/Hand/original/w0712_s01_pWOZ_r03.png (writer=712, prompt=WOZ)
# File /workspace/Hand/original/w0712_s01_pWOZ_r03.png - FilteredLine 0: 훌륭
# Processing: /workspace/Hand/original/w0713_s01_pWOZ_r03.png (writer=713, prompt=WOZ)
# libpng warning: Incorrect bKGD chunk length
# Processing: /workspace/Hand/original/w0714_s01_pWOZ_r03.png (writer=714, prompt=WOZ)
# File /workspace/Hand/original/w0714_s01_pWOZ_r03.png - FilteredLine 0: 발 m음:_
# Processing: /workspace/Hand/original/w0715_s01_pWOZ_r03.png (writer=715, prompt=WOZ)
# File /workspace/Hand/original/w0715_s01_pWOZ_r03.png - FilteredLine 0: 콤구교Q론표국론
# Processing: /workspace/Hand/original/w0717_s01_pWOZ_r03.png (writer=717, prompt=WOZ)
# File /workspace/Hand/original/w0717_s01_pWOZ_r03.png - FilteredLine 0: Kiiin q %rmd Twrwirirjyhr]
# Processing: /workspace/Hand/original/w0719_s01_pWOZ_r03.png (writer=719, prompt=WOZ)
# File /workspace/Hand/original/w0719_s01_pWOZ_r03.png - FilteredLine 0: 'ttnin Aa mhmexfmGifri hai niatimiesr ryely
# Processing: /workspace/Hand/original/w0720_s01_pWOZ_r03.png (writer=720, prompt=WOZ)
# File /workspace/Hand/original/w0720_s01_pWOZ_r03.png - FilteredLine 0: ~hrn R   Srrfuifne sShxruasyipbrn hnihy

# %% [markdown]
# # 475개 확보
